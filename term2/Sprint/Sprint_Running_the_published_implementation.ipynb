# %% [markdown]
# ##Sprint 公開されている実装を動かす
# ###1.このSprintについて
#
#
# ####Sprintの目的
# 公開されている実装を動かす際のノウハウを得る
# 論文で読んだ手法を動かしてみる
#
# どのように学ぶか
# 論文で読んだ手法の公開されている実装を実際に動かしていきます。
#
#
# ###2.Faster R-CNN
#
#
# ####Faster R-CNN[1]の実装を動かします。
#
# [1]Ren, S., He, K., Girshick, R., Sun, J.: Faster r-cnn: Towards real-time object detection with region proposal networks. In: Advances in neural information processing systems. (2015) 91–99
#
# [https://arxiv.org/pdf/1506.01497.pdf](https://arxiv.org/pdf/1506.01497.pdf)
#
# 以下のものを使用してください。Kerasを使用した実装です。
#
# [duckrabbits/ObjectDetection at master](https://github.com/duckrabbits/ObjectDetection/tree/master)

# %% [markdown]
# 【問題1】学習と推定
# READMEを参考に上記実装を動かしてください。

# %%
# !pip install tensorflow==1.15.0
# Out:
# Collecting tensorflow==1.15.0
#   Downloading https://files.pythonhosted.org/packages/92/2b/e3af15221da9ff323521565fa3324b0d7c7c5b1d7a8ca66984c8d59cb0ce/tensorflow-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 41kB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (0.36.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.19.5)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 55.7MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.12.1)
# Collecting keras-applications>=1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 7.2MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (0.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.15.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 55.8MB/s
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (3.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.32.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (3.12.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.0) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (54.1.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.7.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.7.4.3)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=486ab1accf58c7d9abc3087cc15cb8dc13a37506e44ef78fcdec4666cd6941c0
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorflow-estimator, keras-applications, tensorboard, gast, tensorflow
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %%
# !pip install keras==2.2.4
# Out:
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 12.6MB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.4.1)
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.4

# %%
import tensorflow

# %%
tensorflow.__version__
# Out:
# '1.15.0'

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.10)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)

# %%
# 自分のマイドライブにマウントする

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !mkdir .kaggle

# %%
# !ls -a
# Out:
# coco_annotation.py  .gitignore		README.md	     yolov3.cfg
# convert.py	    .ipynb_checkpoints	train_bottleneck.py  yolov3-tiny.cfg
# darknet53.cfg	    .kaggle		train.py	     yolov3.weights
# darknet53.conv.74   kmeans.py		train.txt	     yolo_video.py
# darknet53.weights   LICENSE		voc_annotation.py
# font		    model_data		yolo3
# .git		    __pycache__		yolo.py

# %% [markdown]
# # New Section

# %%
# # https://www.kaggle.com/　へアクセスし、ログイン後に右上のプロフィール画像をクリック、さらに"My Account"をクリックする
# # このサイトの「API」項目にある"Create New API Token"をクリックすると、kaggle.jsonファイルが自動的にダウンロードされる
# # ローカルで、kaggle.json（ダウンロードフォルダにあるはず）をエディターで開く。
# # このセルの以下のコードにある token = {'username':'***','key':'***'} における「***」部分を、
# # ダウンロードしたkaggle.jsonを参照して書き換え、このセルを実行する

# import json

# token = {"username":"______________","key":"__________-"}
# with open('/content/.kaggle/kaggle.json', 'w') as file:
#     json.dump(token, file)

# %%
# !chmod 600 /content/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/content/.kaggle/kaggle.json': No such file or directory

# %%
# !pwd
# Out:
# /content/drive/My Drive/keras-yolo3

# %%
# !ls -a .kaggle
# Out:
# .  ..  kaggle.json

# %%
# !mkdir /root/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle/’: File exists

# %%
# !cp -R /content/.kaggle/kaggle.json /root/.kaggle/
# Out:
# cp: cannot stat '/content/.kaggle/kaggle.json': No such file or directory

# %%
# !ls -a /root/.kaggle/
# Out:
# .  ..  kaggle.json

# %%
# !cat /root/.kaggle/kaggle.json
# Out:
# {"username": "yoheiogawa19", "key": "7e7b92710d8e8aa6bdff5259eaa0cf7b"}

# %%
# kaggle APIコマンドが使えるかどうかを確認


# !kaggle competitions list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes         98           False
# gan-getting-started                            2030-07-01 23:59:00  Getting Started     Prizes        208           False
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge        477           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       3250           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      26244           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       6616            True
# connectx                                       2030-01-01 00:00:00  Getting Started  Knowledge        579           False
# nlp-getting-started                            2030-01-01 00:00:00  Getting Started  Knowledge       1671           False
# competitive-data-science-predict-future-sales  2022-12-31 23:59:00  Playground           Kudos      10746            True
# jane-street-market-prediction                  2021-08-23 23:59:00  Featured          $100,000       4245           False
# hungry-geese                                   2021-07-26 23:59:00  Playground          Prizes        410           False
# coleridgeinitiative-show-us-the-data           2021-06-22 23:59:00  Featured           $90,000        105           False
# bms-molecular-translation                      2021-06-02 23:59:00  Featured           $50,000        324           False
# iwildcam2021-fgvc8                             2021-05-26 23:59:00  Research         Knowledge          6           False
# herbarium-2021-fgvc8                           2021-05-26 23:59:00  Research         Knowledge         27           False
# plant-pathology-2021-fgvc8                     2021-05-26 23:59:00  Research         Knowledge         95           False
# hotel-id-2021-fgvc8                            2021-05-26 23:59:00  Research         Knowledge         20           False
# hashcode-2021-oqr-extension                    2021-05-25 23:59:00  Playground       Knowledge         94           False
# indoor-location-navigation                     2021-05-17 23:59:00  Research           $10,000        684            True
# hpa-single-cell-image-classification           2021-05-11 23:59:00  Featured           $25,000        396           False

# %%
# カレントディレクトリの変更

import os

os.chdir('/content/drive/My Drive/')

# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content/drive/My Drive

# %%
# simpsonデータセットのAPIコマンドでデータセットをダウンロードする
# APIコマンドはこちらのサイトを参照。https://www.kaggle.com/alexattia/the-simpsons-characters-dataset

# !kaggle datasets download -d alexattia/the-simpsons-characters-dataset --force
# Out:
# Downloading the-simpsons-characters-dataset.zip to /content/drive/My Drive
#  99% 1.07G/1.08G [00:30<00:00, 50.2MB/s]
# 100% 1.08G/1.08G [00:30<00:00, 37.5MB/s]

# %%
# !unzip /content/drive/'My Drive'/the-simpsons-characters-dataset.zip  -d Simpsons
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1270.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1271.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1272.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1273.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1274.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1275.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1276.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1277.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1278.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1279.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1280.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1281.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1282.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1283.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1284.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1285.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1286.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1287.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1288.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1289.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1290.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1291.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1292.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1293.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1294.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1295.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1296.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1297.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1298.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1299.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1300.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1301.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1302.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1303.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1304.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1305.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1306.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1307.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1308.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1309.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1310.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1311.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1312.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1313.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1314.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1315.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1316.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1317.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1318.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1319.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1320.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1321.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1322.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1323.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1324.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1325.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1326.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1327.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1328.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1329.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1330.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1331.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1332.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1333.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1334.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1335.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1336.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1337.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1338.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1339.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1340.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1341.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1342.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1343.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1344.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1345.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1346.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1347.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1348.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1349.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1350.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1351.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1352.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1353.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1354.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1355.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1356.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1357.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1358.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1359.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1360.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1361.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1362.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1363.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1364.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1365.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1366.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1367.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1368.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1369.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1370.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1371.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1372.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1373.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1374.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1375.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1376.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1377.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1378.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1379.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1380.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1381.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1382.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1383.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1384.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1385.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1386.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1387.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1388.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1389.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1390.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1391.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1392.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1393.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1394.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1395.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1396.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1397.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1398.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1399.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1400.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1401.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1402.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1403.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1404.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1405.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1406.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1407.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1408.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1409.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1410.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1411.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1412.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1413.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1414.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1415.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1416.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1417.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1418.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1419.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1420.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1421.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1422.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1423.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1424.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1425.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1426.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1427.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1428.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1429.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1430.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1431.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1432.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1433.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1434.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1435.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1436.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1437.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1438.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1439.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1440.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1441.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1442.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1443.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1444.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1445.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1446.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1447.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1448.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1449.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1450.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/moe_szyslak/pic_1451.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0000.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0001.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0002.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0003.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0004.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0005.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0006.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0007.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0008.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0009.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0010.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0011.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0012.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0013.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0014.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0015.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0016.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0017.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0018.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0019.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0020.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0021.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0022.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0023.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0024.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0025.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0026.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0027.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0028.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0029.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0030.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0031.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0032.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0033.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0034.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0035.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0036.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0037.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0038.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0039.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0040.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0041.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0042.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0043.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0044.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0045.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0046.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0047.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0048.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0049.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0050.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0051.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0052.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0053.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0054.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0055.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0056.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0057.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0058.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0059.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0060.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0061.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0062.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0063.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0064.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0065.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0066.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0067.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0068.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0069.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0070.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0071.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0072.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0073.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0074.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0075.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0076.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0077.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0078.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0079.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0080.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0081.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0082.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0083.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0084.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0085.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0086.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0087.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0088.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0089.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0090.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0091.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0092.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0093.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0094.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0095.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0096.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0097.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0098.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0099.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0100.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0101.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0102.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0103.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0104.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0105.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0106.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0107.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0108.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0109.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0110.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0111.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0112.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0113.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0114.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0115.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0116.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0117.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0118.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0119.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0120.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0121.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0122.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0123.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0124.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0125.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0126.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0127.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0128.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0129.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0130.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0131.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0132.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0133.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0134.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0135.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0136.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0137.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0138.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0139.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0140.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0141.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0142.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0143.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0144.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0145.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0146.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0147.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0148.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0149.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0150.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0151.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0152.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0153.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0154.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0155.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0156.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0157.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0158.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0159.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0160.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0161.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0162.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0163.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0164.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0165.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0166.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0167.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0168.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0169.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0170.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0171.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0172.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0173.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0174.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0175.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0176.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0177.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0178.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0179.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0180.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0181.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0182.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0183.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0184.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0185.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0186.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0187.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0188.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0189.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0190.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0191.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0192.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0193.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0194.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0195.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0196.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0197.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0198.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0199.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0200.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0201.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0202.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0203.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0204.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0205.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0206.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0207.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0208.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0209.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0210.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0211.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0212.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0213.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0214.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0215.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0216.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0217.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0218.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0219.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0220.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0221.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0222.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0223.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0224.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0225.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0226.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0227.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0228.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0229.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0230.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0231.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0232.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0233.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0234.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0235.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0236.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0237.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0238.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0239.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0240.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0241.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0242.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0243.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0244.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0245.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0246.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0247.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0248.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0249.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0250.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0251.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0252.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0253.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0254.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0255.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0256.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0257.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0258.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0259.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0260.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0261.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0262.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0263.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0264.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0265.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0266.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0267.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0268.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0269.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0270.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0271.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0272.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0273.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0274.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0275.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0276.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0277.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0278.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0279.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0280.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0281.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0282.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0283.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0284.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0285.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0286.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0287.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0288.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0289.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0290.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0291.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0292.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0293.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0294.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0295.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0296.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0297.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0298.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0299.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0300.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0301.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0302.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0303.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0304.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0305.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0306.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0307.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0308.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0309.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0310.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0311.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0312.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0313.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0314.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0315.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0316.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0317.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0318.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0319.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0320.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0321.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0322.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0323.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0324.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0325.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0326.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0327.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0328.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0329.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0330.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0331.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0332.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0333.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0334.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0335.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0336.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0337.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0338.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0339.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0340.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0341.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0342.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0343.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0344.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0345.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0346.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0347.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0348.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0349.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0350.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0351.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0352.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0353.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0354.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0355.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0356.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0357.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0358.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0359.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0360.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0361.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0362.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0363.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0364.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0365.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0366.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0367.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0368.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0369.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0370.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0371.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0372.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0373.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0374.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0375.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0376.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0377.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0378.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0379.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0380.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0381.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0382.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0383.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0384.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0385.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0386.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0387.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0388.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0389.jpg
#   inflating: Simpsons/simpsons_dataset/simpsons_dataset/ned_flanders/pic_0390.jpg
# ...
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0016.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0017.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0018.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0019.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0020.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0021.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0022.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0023.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0024.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0025.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0026.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0027.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0028.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0029.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0030.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0031.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0032.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0033.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0034.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0035.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0036.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0037.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0038.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0039.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0040.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0041.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0042.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0043.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0044.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0045.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0046.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0047.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0048.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0049.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0050.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0051.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0052.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0053.jpg
#   inflating: Simpsons/simpsons_dataset/snake_jailbird/pic_0054.jpg
#   inflating: Simpsons/simpsons_dataset/troy_mcclure/pic_0000.jpg
#   inflating: Simpsons/simpsons_dataset/troy_mcclure/pic_0001.jpg
#   inflating: Simpsons/simpsons_dataset/troy_mcclure/pic_0002.jpg
#   inflating: Simpsons/simpsons_dataset/troy_mcclure/pic_0003.jpg
#   inflating: Simpsons/simpsons_dataset/troy_mcclure/pic_0004.jpg
#   inflating: Simpsons/simpsons_dataset/troy_mcclure/pic_0005.jpg
#   inflating: Simpsons/simpsons_dataset/troy_mcclure/pic_0006.jpg
#   inflating: Simpsons/simpsons_dataset/troy_mcclure/pic_0007.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0000.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0001.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0002.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0003.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0004.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0005.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0006.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0007.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0008.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0009.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0010.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0011.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0012.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0013.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0014.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0015.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0016.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0017.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0018.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0019.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0020.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0021.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0022.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0023.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0024.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0025.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0026.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0027.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0028.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0029.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0030.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0031.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0032.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0033.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0034.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0035.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0036.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0037.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0038.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0039.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0040.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0041.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0042.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0043.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0044.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0045.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0046.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0047.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0048.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0049.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0050.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0051.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0052.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0053.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0054.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0055.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0056.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0057.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0058.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0059.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0060.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0061.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0062.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0063.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0064.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0065.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0066.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0067.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0068.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0069.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0070.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0071.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0072.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0073.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0074.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0075.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0076.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0077.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0078.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0079.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0080.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0081.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0082.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0083.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0084.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0085.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0086.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0087.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0088.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0089.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0090.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0091.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0092.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0093.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0094.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0095.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0096.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0097.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0098.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0099.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0100.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0101.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0102.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0103.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0104.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0105.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0106.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0107.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0108.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0109.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0110.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0111.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0112.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0113.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0114.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0115.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0116.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0117.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0118.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0119.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0120.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0121.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0122.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0123.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0124.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0125.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0126.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0127.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0128.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0129.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0130.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0131.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0132.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0133.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0134.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0135.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0136.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0137.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0138.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0139.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0140.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0141.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0142.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0143.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0144.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0145.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0146.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0147.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0148.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0149.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0150.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0151.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0152.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0153.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0154.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0155.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0156.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0157.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0158.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0159.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0160.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0161.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0162.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0163.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0164.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0165.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0166.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0167.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0168.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0169.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0170.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0171.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0172.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0173.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0174.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0175.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0176.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0177.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0178.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0179.jpg
#   inflating: Simpsons/simpsons_dataset/waylon_smithers/pic_0180.jpg
#   inflating: Simpsons/weights.best.hdf5

# %%
# !git clone https://github.com/duckrabbits/ObjectDetection.git
# Out:
# fatal: destination path 'ObjectDetection' already exists and is not an empty directory.

# %%
# https://github.com/duckrabbits/ObjectDetection/tree/master
# この後、上述のgithubのreadmeに沿って、simpsons_datasetフォルダをプロジェクトフォルダ配下に格納しましょう。
# testデータなども同様に準備してみよう。

# %%
# %mv Simpsons/simpsons_dataset ObjectDetection/

# %%
# %cd ObjectDetection/
# Out:
# /content/drive/My Drive/ObjectDetection

# %%
ls
# Out:
# annotation.txt  ObjectDetection/  predict.py  save/              train.py
# model/          out.csv           README.md   simpsons_dataset/

# %%
# !python  train.py -p annotation.txt
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class (19 classes) :
# {'abraham_grampa_simpson': 687,
#  'apu_nahasapeemapetilon': 206,
#  'bart_simpson': 650,
#  'bg': 0,
#  'charles_montgomery_burns': 650,
#  'chief_wiggum': 209,
#  'comic_book_guy': 208,
#  'edna_krabappel': 212,
#  'homer_simpson': 718,
#  'kent_brockman': 213,
#  'krusty_the_clown': 429,
#  'lisa_simpson': 756,
#  'marge_simpson': 629,
#  'milhouse_van_houten': 210,
#  'moe_szyslak': 403,
#  'ned_flanders': 675,
#  'nelson_muntz': 219,
#  'principal_skinner': 614,
#  'sideshow_bob': 201}
# -------------------------------
# path to config file : ./save/train_20210326-054140_config.pickle
# -------------------------------
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/ObjectDetection/model/RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 4, 4)         0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 4, 14, 14, 10 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 4, 7, 7, 512) 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 4, 7, 7, 512) 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 4, 7, 7, 512) 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 4, 7, 7, 2048 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 4, 7, 7, 2048 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 7, 7, 2048 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 7, 7, 2048 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 4, 7, 7, 512) 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 7, 7, 512) 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 7, 7, 512) 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 7, 7, 2048 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 7, 7, 2048 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 4, 7, 7, 512) 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 7, 7, 512) 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 7, 7, 512) 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, 7, 7, 2048 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 7, 7, 2048 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 4, 1, 1, 2048 0           activation_49[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 4, 2048)      0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 1 6156        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 4 24624       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_19 (TimeDistributed (None, 4, 19)        38931       time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_19 (TimeDistribut (None, 4, 72)        147528      time_distributed_1[0][0]
# ==================================================================================================
# Total params: 28,524,055
# Trainable params: 28,417,815
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2021-03-26 05:42:15.868839: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-03-26 05:42:15.939558: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2021-03-26 05:42:15.939837: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e5c9a80840 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-03-26 05:42:15.939870: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-03-26 05:42:15.944077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-03-26 05:42:16.135220: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:42:16.136189: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e5c9a80d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-03-26 05:42:16.136224: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-03-26 05:42:16.137615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:42:16.138300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-03-26 05:42:16.150192: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-26 05:42:16.358903: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-03-26 05:42:16.449549: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-03-26 05:42:16.470439: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-03-26 05:42:16.711920: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-03-26 05:42:16.853168: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-03-26 05:42:17.353121: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-26 05:42:17.353313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:42:17.354078: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:42:17.354642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-03-26 05:42:17.354846: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-26 05:42:17.357271: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-26 05:42:17.357305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-03-26 05:42:17.357318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-03-26 05:42:17.372161: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:42:17.372898: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:42:17.380089: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-03-26 05:42:17.380156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2021-03-26 05:42:18.730773: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of system memory.
# 2021-03-26 05:42:18.747784: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of system memory.
# 2021-03-26 05:42:18.817043: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of system memory.
# 2021-03-26 05:42:18.878072: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of system memory.
# 2021-03-26 05:42:18.926219: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of system memory.
# 2021-03-26 05:42:29.760646: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-26 05:42:34.185050: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 10/10 [==============================] - 37s 4s/step - rpn_cls: 6.7087 - rpn_regr: 0.1097 - detector_cls: 5.1402 - detector_regr: 4.0383
# Average number of overlapping bounding boxes from RPN = 9.6 for 10 previous iterations
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.272727272727273
# Classifier accuracy for bounding boxes from RPN: 0.4
# Loss RPN classifier: 6.626292181015015
# Loss RPN regression: 0.0925095658749342
# Loss Detector classifier: 6.8110413432121275
# Loss Detector regression: 8.164248225092887
# Elapsed time: 36.92303800582886[s]
# Total loss decreased from inf to 21.694091315194964, saving weights
# Epoch 2/10
#  9/10 [==========================>...] - ETA: 0s - rpn_cls: 1.3695 - rpn_regr: 0.1057 - detector_cls: 6.1887 - detector_regr: 3.2693Average number of overlapping bounding boxes from RPN = 18.4 for 10 previous iterations
# 10/10 [==============================] - 3s 290ms/step - rpn_cls: 1.3681 - rpn_regr: 0.1076 - detector_cls: 6.1561 - detector_regr: 3.1132
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.09090909090909
# Classifier accuracy for bounding boxes from RPN: 0.55
# Loss RPN classifier: 1.355785311041472
# Loss RPN regression: 0.12456372044980527
# Loss Detector classifier: 5.862987673282625
# Loss Detector regression: 1.7090205654501915
# Elapsed time: 24.460848569869995[s]
# Total loss decreased from 21.694091315194964 to 9.052357270224094, saving weights
# Epoch 3/10
#  8/10 [=======================>......] - ETA: 0s - rpn_cls: 3.7473 - rpn_regr: 0.2283 - detector_cls: 2.3899 - detector_regr: 0.6512Average number of overlapping bounding boxes from RPN = 18.9 for 10 previous iterations
# 10/10 [==============================] - 2s 213ms/step - rpn_cls: 3.4284 - rpn_regr: 0.2148 - detector_cls: 2.3358 - detector_regr: 0.6379
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.454545454545453
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.04016302115208
# Loss RPN regression: 0.15415075458586217
# Loss Detector classifier: 2.0745869755744932
# Loss Detector regression: 0.5730854123830795
# Elapsed time: 3.380685567855835[s]
# Total loss decreased from 9.052357270224094 to 4.841986163695514, saving weights
# Epoch 4/10
#  7/10 [====================>.........] - ETA: 0s - rpn_cls: 2.9732 - rpn_regr: 0.1674 - detector_cls: 2.5334 - detector_regr: 0.8498Average number of overlapping bounding boxes from RPN = 23.4 for 10 previous iterations
# 10/10 [==============================] - 3s 274ms/step - rpn_cls: 2.8672 - rpn_regr: 0.1547 - detector_cls: 2.4620 - detector_regr: 0.8221
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.545454545454547
# Classifier accuracy for bounding boxes from RPN: 0.575
# Loss RPN classifier: 2.4677935617801268
# Loss RPN regression: 0.1184458326548338
# Loss Detector classifier: 2.348998463153839
# Loss Detector regression: 0.7372910469770432
# Elapsed time: 3.6673738956451416[s]
# Epoch 5/10
#  6/10 [=================>............] - ETA: 0s - rpn_cls: 0.2065 - rpn_regr: 0.1614 - detector_cls: 2.2548 - detector_regr: 0.6762Average number of overlapping bounding boxes from RPN = 15.0 for 10 previous iterations
# 10/10 [==============================] - 2s 218ms/step - rpn_cls: 0.7396 - rpn_regr: 0.1512 - detector_cls: 2.1881 - detector_regr: 0.6347
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.545454545454547
# Classifier accuracy for bounding boxes from RPN: 0.55
# Loss RPN classifier: 1.4904400764491583
# Loss RPN regression: 0.1351257536560297
# Loss Detector classifier: 2.114381563663483
# Loss Detector regression: 0.6475696474313736
# Elapsed time: 2.3778162002563477[s]
# Total loss decreased from 4.841986163695514 to 4.387517041200044, saving weights
# Epoch 6/10
#  5/10 [==============>...............] - ETA: 1s - rpn_cls: 7.7707 - rpn_regr: 0.0673 - detector_cls: 1.6811 - detector_regr: 0.1950Average number of overlapping bounding boxes from RPN = 16.6 for 10 previous iterations
# 10/10 [==============================] - 3s 326ms/step - rpn_cls: 6.7448 - rpn_regr: 0.0880 - detector_cls: 1.6990 - detector_regr: 0.2999
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.636363636363637
# Classifier accuracy for bounding boxes from RPN: 0.725
# Loss RPN classifier: 5.844217360985931
# Loss RPN regression: 0.099161097407341
# Loss Detector classifier: 1.7275424540042876
# Loss Detector regression: 0.48320481479167937
# Elapsed time: 4.114272594451904[s]
# Epoch 7/10
#  4/10 [===========>..................] - ETA: 1s - rpn_cls: 0.0052 - rpn_regr: 0.1834 - detector_cls: 2.2938 - detector_regr: 0.5456Average number of overlapping bounding boxes from RPN = 18.5 for 10 previous iterations
# 10/10 [==============================] - 2s 236ms/step - rpn_cls: 1.0288 - rpn_regr: 0.1771 - detector_cls: 2.2596 - detector_regr: 0.5863
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 16.818181818181817
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 1.6906102264412766
# Loss RPN regression: 0.1818429658189416
# Loss Detector classifier: 2.276129364967346
# Loss Detector regression: 0.6264266520738602
# Elapsed time: 2.5577657222747803[s]
# Epoch 8/10
#  3/10 [========>.....................] - ETA: 1s - rpn_cls: 4.5894 - rpn_regr: 0.1413 - detector_cls: 2.1242 - detector_regr: 0.7110Average number of overlapping bounding boxes from RPN = 18.4 for 10 previous iterations
# 10/10 [==============================] - 2s 227ms/step - rpn_cls: 3.3395 - rpn_regr: 0.1221 - detector_cls: 2.1662 - detector_regr: 0.6766
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 26.636363636363637
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.137782956287265
# Loss RPN regression: 0.12314520012587309
# Loss Detector classifier: 2.1911746978759767
# Loss Detector regression: 0.6397684127092361
# Elapsed time: 2.515986204147339[s]
# Epoch 9/10
#  2/10 [=====>........................] - ETA: 1s - rpn_cls: 0.0044 - rpn_regr: 0.0684 - detector_cls: 2.2860 - detector_regr: 0.5563Average number of overlapping bounding boxes from RPN = 26.0 for 10 previous iterations
# 10/10 [==============================] - 2s 209ms/step - rpn_cls: 1.9683 - rpn_regr: 0.0986 - detector_cls: 2.2342 - detector_regr: 0.6503
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.363636363636363
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.3425769512575245
# Loss RPN regression: 0.12076970469206572
# Loss Detector classifier: 2.204530620574951
# Loss Detector regression: 0.6513936504721641
# Elapsed time: 2.3102920055389404[s]
# Epoch 10/10
#  1/10 [==>...........................] - ETA: 3s - rpn_cls: 6.4318 - rpn_regr: 0.1597 - detector_cls: 2.3978 - detector_regr: 0.2704Average number of overlapping bounding boxes from RPN = 22.6 for 10 previous iterations
# 10/10 [==============================] - 3s 271ms/step - rpn_cls: 2.2201 - rpn_regr: 0.1572 - detector_cls: 2.2017 - detector_regr: 0.4369
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 25.90909090909091
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 0.8815628032929907
# Loss RPN regression: 0.13505250085145235
# Loss Detector classifier: 2.1898112297058105
# Loss Detector regression: 0.4565976396203041
# Elapsed time: 2.9356842041015625[s]
# Total loss decreased from 4.387517041200044 to 3.6630241734705575, saving weights
# training is done
# -------------------------------
# path to config file : ./save/train_20210326-054140_config.pickle
# -------------------------------

# %%
# !python predict.py -i /content/drive/MyDrive/ObjectDetection/ObjectDetection/kaggle_simpson_testset -c ./save/train_20210326-054140_config.pickle
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/ObjectDetection/model/RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-03-26 05:44:46.635549: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-03-26 05:44:46.639879: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2021-03-26 05:44:46.640066: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56459a7a9d40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-03-26 05:44:46.640097: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-03-26 05:44:46.641737: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-03-26 05:44:46.745885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:44:46.746711: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56459bf1a1c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-03-26 05:44:46.746746: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-03-26 05:44:46.746921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:44:46.747489: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-03-26 05:44:46.747805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-26 05:44:46.748883: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-03-26 05:44:46.749929: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-03-26 05:44:46.750255: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-03-26 05:44:46.751528: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-03-26 05:44:46.752640: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-03-26 05:44:46.755800: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-26 05:44:46.755902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:44:46.756485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:44:46.756990: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-03-26 05:44:46.757046: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-26 05:44:46.758051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-26 05:44:46.758078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-03-26 05:44:46.758088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-03-26 05:44:46.758235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:44:46.758857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 05:44:46.759393: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-03-26 05:44:46.759434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# abraham_grampa_simpson_0.jpg
# 2021-03-26 05:44:49.706668: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-26 05:44:50.400153: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# []
# Elapsed time = 2.4899983406066895[s]
# abraham_grampa_simpson_1.jpg
# []
# Elapsed time = 0.7231884002685547[s]
# abraham_grampa_simpson_10.jpg
# []
# Elapsed time = 0.738210916519165[s]
# abraham_grampa_simpson_11.jpg
# []
# Elapsed time = 0.6489448547363281[s]
# abraham_grampa_simpson_12.jpg
# []
# Elapsed time = 0.5842726230621338[s]
# abraham_grampa_simpson_13.jpg
# []
# Elapsed time = 0.5866992473602295[s]
# abraham_grampa_simpson_14.jpg
# []
# Elapsed time = 0.6981806755065918[s]
# abraham_grampa_simpson_15.jpg
# []
# Elapsed time = 0.5759508609771729[s]
# abraham_grampa_simpson_16.jpg
# []
# Elapsed time = 0.7291829586029053[s]
# abraham_grampa_simpson_17.jpg
# []
# Elapsed time = 0.6508786678314209[s]
# abraham_grampa_simpson_18.jpg
# []
# Elapsed time = 0.5822632312774658[s]
# abraham_grampa_simpson_19.jpg
# []
# Elapsed time = 0.5908901691436768[s]
# abraham_grampa_simpson_2.jpg
# []
# Elapsed time = 0.5741183757781982[s]
# abraham_grampa_simpson_20.jpg
# []
# Elapsed time = 0.6806333065032959[s]
# abraham_grampa_simpson_21.jpg
# []
# Elapsed time = 0.596717357635498[s]
# abraham_grampa_simpson_22.jpg
# []
# Elapsed time = 0.5839669704437256[s]
# abraham_grampa_simpson_23.jpg
# []
# Elapsed time = 0.5822210311889648[s]
# abraham_grampa_simpson_24.jpg
# []
# Elapsed time = 0.5931408405303955[s]
# abraham_grampa_simpson_25.jpg
# []
# Elapsed time = 0.578303337097168[s]
# abraham_grampa_simpson_26.jpg
# []
# Elapsed time = 0.5912296772003174[s]
# abraham_grampa_simpson_27.jpg
# []
# Elapsed time = 0.765296459197998[s]
# abraham_grampa_simpson_28.jpg
# []
# Elapsed time = 0.5868527889251709[s]
# abraham_grampa_simpson_29.jpg
# []
# Elapsed time = 0.5921361446380615[s]
# abraham_grampa_simpson_3.jpg
# []
# Elapsed time = 0.5577101707458496[s]
# abraham_grampa_simpson_30.jpg
# []
# Elapsed time = 0.5756487846374512[s]
# abraham_grampa_simpson_31.jpg
# []
# Elapsed time = 0.5817334651947021[s]
# abraham_grampa_simpson_32.jpg
# []
# Elapsed time = 0.5840833187103271[s]
# abraham_grampa_simpson_33.jpg
# []
# Elapsed time = 0.5929510593414307[s]
# abraham_grampa_simpson_34.jpg
# []
# Elapsed time = 0.5882313251495361[s]
# abraham_grampa_simpson_35.jpg
# []
# Elapsed time = 0.6117925643920898[s]
# abraham_grampa_simpson_36.jpg
# []
# Elapsed time = 0.5779547691345215[s]
# abraham_grampa_simpson_37.jpg
# []
# Elapsed time = 0.578254222869873[s]
# abraham_grampa_simpson_38.jpg
# []
# Elapsed time = 0.5684332847595215[s]
# abraham_grampa_simpson_39.jpg
# []
# Elapsed time = 0.5855836868286133[s]
# abraham_grampa_simpson_4.jpg
# []
# Elapsed time = 0.5717220306396484[s]
# abraham_grampa_simpson_40.jpg
# []
# Elapsed time = 0.5768711566925049[s]
# abraham_grampa_simpson_41.jpg
# []
# Elapsed time = 0.5803775787353516[s]
# abraham_grampa_simpson_42.jpg
# []
# Elapsed time = 0.5886690616607666[s]
# abraham_grampa_simpson_43.jpg
# []
# Elapsed time = 0.6756179332733154[s]
# abraham_grampa_simpson_44.jpg
# []
# Elapsed time = 0.5663692951202393[s]
# abraham_grampa_simpson_45.jpg
# []
# Elapsed time = 0.5859062671661377[s]
# abraham_grampa_simpson_46.jpg
# []
# Elapsed time = 0.5889778137207031[s]
# abraham_grampa_simpson_47.jpg
# []
# Elapsed time = 0.588336706161499[s]
# abraham_grampa_simpson_48.jpg
# []
# Elapsed time = 0.5804140567779541[s]
# abraham_grampa_simpson_49.jpg
# []
# Elapsed time = 0.5529689788818359[s]
# abraham_grampa_simpson_7.jpg
# []
# Elapsed time = 0.5719940662384033[s]
# abraham_grampa_simpson_8.jpg
# []
# Elapsed time = 0.7437129020690918[s]
# abraham_grampa_simpson_9.jpg
# []
# Elapsed time = 0.5795407295227051[s]
# apu_nahasapeemapetilon_0.jpg
# []
# Elapsed time = 0.6076216697692871[s]
# apu_nahasapeemapetilon_1.jpg
# []
# Elapsed time = 0.8391416072845459[s]
# apu_nahasapeemapetilon_10.jpg
# []
# Elapsed time = 0.5632131099700928[s]
# apu_nahasapeemapetilon_11.jpg
# []
# Elapsed time = 0.578728437423706[s]
# apu_nahasapeemapetilon_12.jpg
# []
# Elapsed time = 0.5769493579864502[s]
# apu_nahasapeemapetilon_13.jpg
# []
# Elapsed time = 0.5827052593231201[s]
# apu_nahasapeemapetilon_14.jpg
# []
# Elapsed time = 0.58636474609375[s]
# apu_nahasapeemapetilon_15.jpg
# []
# Elapsed time = 0.5787749290466309[s]
# apu_nahasapeemapetilon_16.jpg
# []
# Elapsed time = 0.601494312286377[s]
# apu_nahasapeemapetilon_17.jpg
# []
# Elapsed time = 0.5527143478393555[s]
# apu_nahasapeemapetilon_18.jpg
# []
# Elapsed time = 0.5771045684814453[s]
# apu_nahasapeemapetilon_19.jpg
# []
# Elapsed time = 0.5905897617340088[s]
# apu_nahasapeemapetilon_2.jpg
# []
# Elapsed time = 0.5411970615386963[s]
# apu_nahasapeemapetilon_20.jpg
# []
# Elapsed time = 0.5899097919464111[s]
# apu_nahasapeemapetilon_21.jpg
# []
# Elapsed time = 0.7068178653717041[s]
# apu_nahasapeemapetilon_22.jpg
# []
# Elapsed time = 0.5772709846496582[s]
# apu_nahasapeemapetilon_23.jpg
# []
# Elapsed time = 0.6031570434570312[s]
# apu_nahasapeemapetilon_24.jpg
# []
# Elapsed time = 0.5732512474060059[s]
# apu_nahasapeemapetilon_25.jpg
# []
# Elapsed time = 0.567317008972168[s]
# apu_nahasapeemapetilon_26.jpg
# []
# Elapsed time = 0.5791940689086914[s]
# apu_nahasapeemapetilon_27.jpg
# []
# Elapsed time = 0.5517356395721436[s]
# apu_nahasapeemapetilon_28.jpg
# []
# Elapsed time = 0.5780978202819824[s]
# apu_nahasapeemapetilon_29.jpg
# []
# Elapsed time = 0.6003873348236084[s]
# apu_nahasapeemapetilon_3.jpg
# []
# Elapsed time = 0.6210532188415527[s]
# apu_nahasapeemapetilon_30.jpg
# []
# Elapsed time = 0.8161706924438477[s]
# apu_nahasapeemapetilon_31.jpg
# []
# Elapsed time = 0.5546426773071289[s]
# apu_nahasapeemapetilon_32.jpg
# []
# Elapsed time = 0.6065914630889893[s]
# apu_nahasapeemapetilon_33.jpg
# []
# Elapsed time = 0.5742552280426025[s]
# apu_nahasapeemapetilon_34.jpg
# []
# Elapsed time = 0.5876522064208984[s]
# apu_nahasapeemapetilon_35.jpg
# []
# Elapsed time = 0.6713025569915771[s]
# apu_nahasapeemapetilon_36.jpg
# []
# Elapsed time = 0.5706503391265869[s]
# apu_nahasapeemapetilon_37.jpg
# []
# Elapsed time = 0.5861632823944092[s]
# apu_nahasapeemapetilon_38.jpg
# []
# Elapsed time = 0.5860552787780762[s]
# apu_nahasapeemapetilon_39.jpg
# []
# Elapsed time = 0.5678756237030029[s]
# apu_nahasapeemapetilon_4.jpg
# []
# Elapsed time = 0.5802505016326904[s]
# apu_nahasapeemapetilon_40.jpg
# []
# Elapsed time = 0.5870976448059082[s]
# apu_nahasapeemapetilon_41.jpg
# []
# Elapsed time = 0.5564055442810059[s]
# apu_nahasapeemapetilon_42.jpg
# []
# Elapsed time = 0.5952374935150146[s]
# apu_nahasapeemapetilon_43.jpg
# []
# Elapsed time = 0.6380703449249268[s]
# apu_nahasapeemapetilon_44.jpg
# []
# Elapsed time = 0.5890552997589111[s]
# apu_nahasapeemapetilon_45.jpg
# []
# Elapsed time = 0.7140984535217285[s]
# apu_nahasapeemapetilon_46.jpg
# []
# Elapsed time = 0.5828766822814941[s]
# apu_nahasapeemapetilon_47.jpg
# []
# Elapsed time = 0.544508695602417[s]
# apu_nahasapeemapetilon_48.jpg
# []
# Elapsed time = 0.5792286396026611[s]
# apu_nahasapeemapetilon_49.jpg
# []
# Elapsed time = 0.5619089603424072[s]
# apu_nahasapeemapetilon_5.jpg
# []
# Elapsed time = 0.6129331588745117[s]
# apu_nahasapeemapetilon_6.jpg
# []
# Elapsed time = 0.5627539157867432[s]
# apu_nahasapeemapetilon_7.jpg
# []
# Elapsed time = 0.5883316993713379[s]
# apu_nahasapeemapetilon_8.jpg
# []
# Elapsed time = 0.5564441680908203[s]
# apu_nahasapeemapetilon_9.jpg
# []
# Elapsed time = 0.5864813327789307[s]
# bart_simpson_0.jpg
# []
# Elapsed time = 0.5504109859466553[s]
# bart_simpson_1.jpg
# []
# Elapsed time = 0.5724070072174072[s]
# bart_simpson_10.jpg
# []
# Elapsed time = 0.565251350402832[s]
# bart_simpson_11.jpg
# []
# Elapsed time = 0.5868029594421387[s]
# bart_simpson_12.jpg
# []
# Elapsed time = 0.5822262763977051[s]
# bart_simpson_13.jpg
# []
# Elapsed time = 0.5538592338562012[s]
# bart_simpson_14.jpg
# []
# Elapsed time = 0.5924880504608154[s]
# bart_simpson_15.jpg
# []
# Elapsed time = 0.587071418762207[s]
# bart_simpson_16.jpg
# []
# Elapsed time = 0.5936110019683838[s]
# bart_simpson_17.jpg
# []
# Elapsed time = 0.5564877986907959[s]
# bart_simpson_18.jpg
# []
# Elapsed time = 0.6059651374816895[s]
# bart_simpson_19.jpg
# []
# Elapsed time = 0.5820529460906982[s]
# bart_simpson_2.jpg
# []
# Elapsed time = 0.582763671875[s]
# bart_simpson_20.jpg
# []
# Elapsed time = 0.5743088722229004[s]
# bart_simpson_21.jpg
# []
# Elapsed time = 0.5627820491790771[s]
# bart_simpson_22.jpg
# []
# Elapsed time = 0.5992732048034668[s]
# bart_simpson_23.jpg
# []
# Elapsed time = 0.5635707378387451[s]
# bart_simpson_24.jpg
# []
# Elapsed time = 0.588097333908081[s]
# bart_simpson_25.jpg
# []
# Elapsed time = 0.5644793510437012[s]
# bart_simpson_26.jpg
# []
# Elapsed time = 0.5602233409881592[s]
# bart_simpson_27.jpg
# []
# Elapsed time = 0.5858807563781738[s]
# bart_simpson_28.jpg
# []
# Elapsed time = 0.5889520645141602[s]
# bart_simpson_29.jpg
# []
# Elapsed time = 0.5460751056671143[s]
# bart_simpson_3.jpg
# []
# Elapsed time = 0.579418420791626[s]
# bart_simpson_30.jpg
# []
# Elapsed time = 0.5682373046875[s]
# bart_simpson_31.jpg
# []
# Elapsed time = 0.6058430671691895[s]
# bart_simpson_32.jpg
# []
# Elapsed time = 0.6001491546630859[s]
# bart_simpson_33.jpg
# []
# Elapsed time = 0.5468900203704834[s]
# bart_simpson_34.jpg
# []
# Elapsed time = 0.5427329540252686[s]
# bart_simpson_35.jpg
# []
# Elapsed time = 0.5939426422119141[s]
# bart_simpson_36.jpg
# []
# Elapsed time = 0.569690465927124[s]
# bart_simpson_37.jpg
# []
# Elapsed time = 0.5566174983978271[s]
# bart_simpson_38.jpg
# []
# Elapsed time = 0.722369909286499[s]
# bart_simpson_39.jpg
# []
# Elapsed time = 0.5978035926818848[s]
# bart_simpson_4.jpg
# []
# Elapsed time = 0.5885183811187744[s]
# bart_simpson_40.jpg
# []
# Elapsed time = 0.57187819480896[s]
# bart_simpson_41.jpg
# []
# Elapsed time = 0.5721249580383301[s]
# bart_simpson_42.jpg
# []
# Elapsed time = 0.5860168933868408[s]
# bart_simpson_43.jpg
# []
# Elapsed time = 0.5836796760559082[s]
# bart_simpson_44.jpg
# []
# Elapsed time = 0.5917673110961914[s]
# bart_simpson_45.jpg
# []
# Elapsed time = 0.6048502922058105[s]
# bart_simpson_46.jpg
# []
# Elapsed time = 0.61220383644104[s]
# bart_simpson_47.jpg
# []
# Elapsed time = 0.5795121192932129[s]
# bart_simpson_48.jpg
# []
# Elapsed time = 0.5937304496765137[s]
# bart_simpson_49.jpg
# []
# Elapsed time = 0.5818109512329102[s]
# bart_simpson_5.jpg
# []
# Elapsed time = 0.5724940299987793[s]
# bart_simpson_6.jpg
# []
# Elapsed time = 0.5952029228210449[s]
# bart_simpson_7.jpg
# []
# Elapsed time = 0.5622603893280029[s]
# bart_simpson_8.jpg
# []
# Elapsed time = 0.5635931491851807[s]
# bart_simpson_9.jpg
# []
# Elapsed time = 0.5958261489868164[s]
# charles_montgomery_burns_0.jpg
# []
# Elapsed time = 0.5951473712921143[s]
# charles_montgomery_burns_1.jpg
# []
# Elapsed time = 0.5763468742370605[s]
# charles_montgomery_burns_10.jpg
# []
# Elapsed time = 0.5839710235595703[s]
# charles_montgomery_burns_11.jpg
# []
# Elapsed time = 0.6086657047271729[s]
# charles_montgomery_burns_12.jpg
# []
# Elapsed time = 0.6857092380523682[s]
# charles_montgomery_burns_13.jpg
# []
# Elapsed time = 0.5654549598693848[s]
# charles_montgomery_burns_14.jpg
# []
# Elapsed time = 0.5726091861724854[s]
# charles_montgomery_burns_15.jpg
# []
# Elapsed time = 0.5723512172698975[s]
# charles_montgomery_burns_16.jpg
# []
# Elapsed time = 0.5920648574829102[s]
# charles_montgomery_burns_17.jpg
# []
# Elapsed time = 0.5829126834869385[s]
# charles_montgomery_burns_18.jpg
# []
# Elapsed time = 0.536949872970581[s]
# charles_montgomery_burns_19.jpg
# []
# Elapsed time = 0.5784499645233154[s]
# charles_montgomery_burns_2.jpg
# []
# Elapsed time = 0.5865035057067871[s]
# charles_montgomery_burns_20.jpg
# []
# Elapsed time = 0.5481758117675781[s]
# charles_montgomery_burns_21.jpg
# []
# Elapsed time = 0.5938310623168945[s]
# charles_montgomery_burns_22.jpg
# []
# Elapsed time = 0.574418306350708[s]
# charles_montgomery_burns_24.jpg
# []
# Elapsed time = 0.6294922828674316[s]
# charles_montgomery_burns_25.jpg
# []
# Elapsed time = 0.579139232635498[s]
# charles_montgomery_burns_26.jpg
# []
# Elapsed time = 0.5891215801239014[s]
# charles_montgomery_burns_27.jpg
# []
# Elapsed time = 0.5744361877441406[s]
# charles_montgomery_burns_28.jpg
# []
# Elapsed time = 0.5770177841186523[s]
# charles_montgomery_burns_29.jpg
# []
# Elapsed time = 0.5775632858276367[s]
# charles_montgomery_burns_3.jpg
# []
# Elapsed time = 0.623741865158081[s]
# charles_montgomery_burns_30.jpg
# []
# Elapsed time = 0.581336498260498[s]
# charles_montgomery_burns_31.jpg
# []
# Elapsed time = 0.5818791389465332[s]
# charles_montgomery_burns_32.jpg
# []
# Elapsed time = 0.5914170742034912[s]
# charles_montgomery_burns_33.jpg
# []
# Elapsed time = 0.5792913436889648[s]
# charles_montgomery_burns_34.jpg
# []
# Elapsed time = 0.5765023231506348[s]
# charles_montgomery_burns_35.jpg
# []
# Elapsed time = 0.5866305828094482[s]
# charles_montgomery_burns_36.jpg
# []
# Elapsed time = 0.5682709217071533[s]
# charles_montgomery_burns_37.jpg
# []
# Elapsed time = 0.5951569080352783[s]
# charles_montgomery_burns_38.jpg
# []
# Elapsed time = 0.570476770401001[s]
# charles_montgomery_burns_39.jpg
# []
# Elapsed time = 0.6297407150268555[s]
# charles_montgomery_burns_4.jpg
# []
# Elapsed time = 0.569669246673584[s]
# charles_montgomery_burns_40.jpg
# []
# Elapsed time = 0.5901987552642822[s]
# charles_montgomery_burns_41.jpg
# []
# Elapsed time = 0.5654244422912598[s]
# charles_montgomery_burns_43.jpg
# []
# Elapsed time = 0.6278424263000488[s]
# charles_montgomery_burns_44.jpg
# []
# Elapsed time = 0.5860655307769775[s]
# charles_montgomery_burns_45.jpg
# []
# Elapsed time = 0.5705156326293945[s]
# charles_montgomery_burns_46.jpg
# []
# Elapsed time = 0.5952506065368652[s]
# charles_montgomery_burns_47.jpg
# []
# Elapsed time = 0.565476655960083[s]
# charles_montgomery_burns_48.jpg
# []
# Elapsed time = 0.5848147869110107[s]
# charles_montgomery_burns_49.jpg
# []
# Elapsed time = 0.571197509765625[s]
# charles_montgomery_burns_5.jpg
# []
# Elapsed time = 0.5439620018005371[s]
# charles_montgomery_burns_6.jpg
# []
# Elapsed time = 0.5778408050537109[s]
# charles_montgomery_burns_7.jpg
# []
# Elapsed time = 0.5727112293243408[s]
# charles_montgomery_burns_8.jpg
# []
# Elapsed time = 0.5663845539093018[s]
# charles_montgomery_burns_9.jpg
# []
# Elapsed time = 0.5890696048736572[s]
# chief_wiggum_0.jpg
# []
# Elapsed time = 0.5833916664123535[s]
# chief_wiggum_1.jpg
# []
# Elapsed time = 0.5686500072479248[s]
# chief_wiggum_10.jpg
# []
# Elapsed time = 0.5754885673522949[s]
# chief_wiggum_11.jpg
# []
# Elapsed time = 0.5618233680725098[s]
# chief_wiggum_12.jpg
# []
# Elapsed time = 0.6162807941436768[s]
# chief_wiggum_13.jpg
# []
# Elapsed time = 0.5843455791473389[s]
# chief_wiggum_14.jpg
# []
# Elapsed time = 0.5793182849884033[s]
# chief_wiggum_15.jpg
# []
# Elapsed time = 0.5746264457702637[s]
# chief_wiggum_16.jpg
# []
# Elapsed time = 0.5732293128967285[s]
# chief_wiggum_17.jpg
# []
# Elapsed time = 0.5591537952423096[s]
# chief_wiggum_18.jpg
# []
# Elapsed time = 0.5872132778167725[s]
# chief_wiggum_19.jpg
# []
# Elapsed time = 0.5793919563293457[s]
# chief_wiggum_2.jpg
# []
# Elapsed time = 0.5435588359832764[s]
# chief_wiggum_20.jpg
# []
# Elapsed time = 0.5766806602478027[s]
# chief_wiggum_21.jpg
# []
# Elapsed time = 0.596698522567749[s]
# chief_wiggum_22.jpg
# []
# Elapsed time = 0.5837302207946777[s]
# chief_wiggum_23.jpg
# []
# Elapsed time = 0.571441650390625[s]
# chief_wiggum_24.jpg
# []
# Elapsed time = 0.5787930488586426[s]
# chief_wiggum_25.jpg
# []
# Elapsed time = 0.5363078117370605[s]
# chief_wiggum_26.jpg
# []
# Elapsed time = 0.5988404750823975[s]
# chief_wiggum_27.jpg
# []
# Elapsed time = 0.5726299285888672[s]
# chief_wiggum_28.jpg
# []
# Elapsed time = 0.5776774883270264[s]
# chief_wiggum_29.jpg
# []
# Elapsed time = 0.5481748580932617[s]
# chief_wiggum_3.jpg
# []
# Elapsed time = 0.7662513256072998[s]
# chief_wiggum_30.jpg
# []
# Elapsed time = 0.5842454433441162[s]
# chief_wiggum_31.jpg
# []
# Elapsed time = 0.5781593322753906[s]
# chief_wiggum_32.jpg
# []
# Elapsed time = 0.6180078983306885[s]
# chief_wiggum_33.jpg
# []
# Elapsed time = 0.5853698253631592[s]
# chief_wiggum_34.jpg
# []
# Elapsed time = 0.5851409435272217[s]
# chief_wiggum_35.jpg
# []
# Elapsed time = 0.5829322338104248[s]
# chief_wiggum_36.jpg
# []
# Elapsed time = 0.5714545249938965[s]
# chief_wiggum_37.jpg
# []
# Elapsed time = 0.5762856006622314[s]
# chief_wiggum_38.jpg
# []
# Elapsed time = 0.5759236812591553[s]
# chief_wiggum_39.jpg
# []
# Elapsed time = 0.5762209892272949[s]
# chief_wiggum_4.jpg
# []
# Elapsed time = 0.6140661239624023[s]
# chief_wiggum_40.jpg
# []
# Elapsed time = 0.6172802448272705[s]
# chief_wiggum_41.jpg
# []
# Elapsed time = 0.5720036029815674[s]
# chief_wiggum_42.jpg
# []
# Elapsed time = 0.5815608501434326[s]
# chief_wiggum_43.jpg
# []
# Elapsed time = 0.596552848815918[s]
# chief_wiggum_44.jpg
# []
# Elapsed time = 0.5835263729095459[s]
# chief_wiggum_45.jpg
# []
# Elapsed time = 0.6281843185424805[s]
# chief_wiggum_46.jpg
# []
# Elapsed time = 0.5761077404022217[s]
# chief_wiggum_47.jpg
# []
# Elapsed time = 0.6567842960357666[s]
# chief_wiggum_48.jpg
# []
# Elapsed time = 0.5567305088043213[s]
# chief_wiggum_49.jpg
# []
# Elapsed time = 0.6070733070373535[s]
# chief_wiggum_5.jpg
# []
# Elapsed time = 0.5721678733825684[s]
# chief_wiggum_6.jpg
# []
# Elapsed time = 0.5786528587341309[s]
# chief_wiggum_7.jpg
# []
# Elapsed time = 0.5570852756500244[s]
# chief_wiggum_8.jpg
# []
# Elapsed time = 0.597130298614502[s]
# chief_wiggum_9.jpg
# []
# Elapsed time = 0.5831642150878906[s]
# comic_book_guy_0.jpg
# []
# Elapsed time = 0.585188627243042[s]
# comic_book_guy_1.jpg
# []
# Elapsed time = 0.6553919315338135[s]
# comic_book_guy_10.jpg
# []
# Elapsed time = 0.6078293323516846[s]
# comic_book_guy_11.jpg
# []
# Elapsed time = 0.5866222381591797[s]
# comic_book_guy_12.jpg
# []
# Elapsed time = 0.5514223575592041[s]
# comic_book_guy_13.jpg
# []
# Elapsed time = 0.5533790588378906[s]
# comic_book_guy_14.jpg
# []
# Elapsed time = 0.5821061134338379[s]
# comic_book_guy_15.jpg
# []
# Elapsed time = 0.5769615173339844[s]
# comic_book_guy_16.jpg
# []
# Elapsed time = 0.5587375164031982[s]
# comic_book_guy_17.jpg
# []
# Elapsed time = 0.5467691421508789[s]
# comic_book_guy_18.jpg
# []
# Elapsed time = 0.5776247978210449[s]
# comic_book_guy_19.jpg
# []
# Elapsed time = 0.7432501316070557[s]
# comic_book_guy_2.jpg
# []
# Elapsed time = 0.5572690963745117[s]
# comic_book_guy_20.jpg
# []
# Elapsed time = 0.5753335952758789[s]
# comic_book_guy_21.jpg
# []
# Elapsed time = 0.5747456550598145[s]
# comic_book_guy_22.jpg
# []
# Elapsed time = 0.5936932563781738[s]
# comic_book_guy_23.jpg
# []
# Elapsed time = 0.5683653354644775[s]
# comic_book_guy_24.jpg
# []
# Elapsed time = 0.5822453498840332[s]
# comic_book_guy_25.jpg
# []
# Elapsed time = 0.5851233005523682[s]
# comic_book_guy_26.jpg
# []
# Elapsed time = 0.5454182624816895[s]
# comic_book_guy_27.jpg
# []
# Elapsed time = 0.5690937042236328[s]
# comic_book_guy_28.jpg
# []
# Elapsed time = 0.5988729000091553[s]
# comic_book_guy_29.jpg
# []
# Elapsed time = 0.5811796188354492[s]
# comic_book_guy_3.jpg
# []
# Elapsed time = 0.6197998523712158[s]
# comic_book_guy_30.jpg
# []
# Elapsed time = 0.5841858386993408[s]
# comic_book_guy_31.jpg
# []
# Elapsed time = 0.6187114715576172[s]
# comic_book_guy_32.jpg
# []
# Elapsed time = 0.566077709197998[s]
# comic_book_guy_33.jpg
# []
# Elapsed time = 0.5724530220031738[s]
# comic_book_guy_34.jpg
# []
# Elapsed time = 0.5502510070800781[s]
# comic_book_guy_36.jpg
# []
# Elapsed time = 0.5662171840667725[s]
# comic_book_guy_37.jpg
# []
# Elapsed time = 0.5449004173278809[s]
# comic_book_guy_38.jpg
# []
# Elapsed time = 0.5655393600463867[s]
# comic_book_guy_39.jpg
# []
# Elapsed time = 0.5406463146209717[s]
# comic_book_guy_4.jpg
# []
# Elapsed time = 0.5692281723022461[s]
# comic_book_guy_40.jpg
# []
# Elapsed time = 0.5647649765014648[s]
# comic_book_guy_41.jpg
# []
# Elapsed time = 0.6235597133636475[s]
# comic_book_guy_42.jpg
# []
# Elapsed time = 0.6066687107086182[s]
# comic_book_guy_43.jpg
# []
# Elapsed time = 0.5676975250244141[s]
# comic_book_guy_44.jpg
# []
# Elapsed time = 0.5355246067047119[s]
# comic_book_guy_45.jpg
# []
# Elapsed time = 0.5338129997253418[s]
# comic_book_guy_46.jpg
# []
# Elapsed time = 0.5932326316833496[s]
# comic_book_guy_47.jpg
# []
# Elapsed time = 0.5887060165405273[s]
# comic_book_guy_48.jpg
# []
# Elapsed time = 0.5854170322418213[s]
# comic_book_guy_49.jpg
# []
# Elapsed time = 0.5564091205596924[s]
# comic_book_guy_5.jpg
# []
# Elapsed time = 0.5846283435821533[s]
# comic_book_guy_6.jpg
# []
# Elapsed time = 0.5616335868835449[s]
# comic_book_guy_7.jpg
# []
# Elapsed time = 0.5757195949554443[s]
# comic_book_guy_8.jpg
# []
# Elapsed time = 0.6145467758178711[s]
# comic_book_guy_9.jpg
# []
# Elapsed time = 0.5925145149230957[s]
# edna_krabappel_0.jpg
# []
# Elapsed time = 0.5411591529846191[s]
# edna_krabappel_1.jpg
# []
# Elapsed time = 0.571009635925293[s]
# edna_krabappel_10.jpg
# []
# Elapsed time = 0.7123403549194336[s]
# edna_krabappel_11.jpg
# []
# Elapsed time = 0.6073439121246338[s]
# edna_krabappel_12.jpg
# []
# Elapsed time = 0.5815184116363525[s]
# edna_krabappel_13.jpg
# []
# Elapsed time = 0.6311953067779541[s]
# edna_krabappel_14.jpg
# []
# Elapsed time = 0.5385410785675049[s]
# edna_krabappel_15.jpg
# []
# Elapsed time = 0.5780768394470215[s]
# edna_krabappel_16.jpg
# []
# Elapsed time = 0.5455644130706787[s]
# edna_krabappel_17.jpg
# []
# Elapsed time = 0.582042932510376[s]
# edna_krabappel_18.jpg
# []
# Elapsed time = 0.6086075305938721[s]
# edna_krabappel_19.jpg
# []
# Elapsed time = 0.6083159446716309[s]
# edna_krabappel_2.jpg
# []
# Elapsed time = 0.6189947128295898[s]
# edna_krabappel_20.jpg
# []
# Elapsed time = 0.590989351272583[s]
# edna_krabappel_21.jpg
# []
# Elapsed time = 0.5762841701507568[s]
# edna_krabappel_22.jpg
# []
# Elapsed time = 0.5919992923736572[s]
# edna_krabappel_23.jpg
# []
# Elapsed time = 0.559255838394165[s]
# edna_krabappel_24.jpg
# []
# Elapsed time = 0.5859885215759277[s]
# edna_krabappel_25.jpg
# []
# Elapsed time = 0.5983731746673584[s]
# edna_krabappel_26.jpg
# []
# Elapsed time = 0.5969719886779785[s]
# edna_krabappel_27.jpg
# []
# Elapsed time = 0.558640718460083[s]
# edna_krabappel_28.jpg
# []
# Elapsed time = 0.5896821022033691[s]
# edna_krabappel_29.jpg
# []
# Elapsed time = 0.581885576248169[s]
# edna_krabappel_3.jpg
# []
# Elapsed time = 0.5556275844573975[s]
# edna_krabappel_30.jpg
# []
# Elapsed time = 0.5913450717926025[s]
# edna_krabappel_31.jpg
# []
# Elapsed time = 0.5610494613647461[s]
# edna_krabappel_32.jpg
# []
# Elapsed time = 0.5946285724639893[s]
# edna_krabappel_33.jpg
# []
# Elapsed time = 0.5701427459716797[s]
# edna_krabappel_34.jpg
# []
# Elapsed time = 0.5377352237701416[s]
# edna_krabappel_35.jpg
# []
# Elapsed time = 0.7398169040679932[s]
# edna_krabappel_36.jpg
# []
# Elapsed time = 0.6042921543121338[s]
# edna_krabappel_37.jpg
# []
# Elapsed time = 0.7646799087524414[s]
# edna_krabappel_38.jpg
# []
# Elapsed time = 0.6124553680419922[s]
# edna_krabappel_39.jpg
# []
# Elapsed time = 0.5522041320800781[s]
# edna_krabappel_4.jpg
# []
# Elapsed time = 0.5387885570526123[s]
# edna_krabappel_40.jpg
# []
# Elapsed time = 0.5428357124328613[s]
# edna_krabappel_41.jpg
# []
# Elapsed time = 0.5593879222869873[s]
# edna_krabappel_42.jpg
# []
# Elapsed time = 0.592125415802002[s]
# edna_krabappel_43.jpg
# []
# Elapsed time = 0.5843207836151123[s]
# edna_krabappel_44.jpg
# []
# Elapsed time = 0.5933167934417725[s]
# edna_krabappel_45.jpg
# []
# Elapsed time = 0.5494458675384521[s]
# edna_krabappel_46.jpg
# []
# Elapsed time = 0.5767407417297363[s]
# edna_krabappel_47.jpg
# []
# Elapsed time = 0.5438680648803711[s]
# edna_krabappel_48.jpg
# []
# Elapsed time = 0.5977575778961182[s]
# edna_krabappel_49.jpg
# []
# Elapsed time = 0.5705852508544922[s]
# edna_krabappel_5.jpg
# []
# Elapsed time = 0.563227653503418[s]
# edna_krabappel_6.jpg
# []
# Elapsed time = 0.5809116363525391[s]
# edna_krabappel_7.jpg
# []
# Elapsed time = 0.5810825824737549[s]
# edna_krabappel_8.jpg
# []
# Elapsed time = 0.6092567443847656[s]
# edna_krabappel_9.jpg
# []
# Elapsed time = 0.5619652271270752[s]
# homer_simpson_0.jpg
# []
# Elapsed time = 0.5653660297393799[s]
# homer_simpson_1.jpg
# []
# Elapsed time = 0.566960334777832[s]
# homer_simpson_10.jpg
# []
# Elapsed time = 0.5778498649597168[s]
# homer_simpson_11.jpg
# []
# Elapsed time = 0.5925514698028564[s]
# homer_simpson_12.jpg
# []
# Elapsed time = 0.5790371894836426[s]
# homer_simpson_13.jpg
# []
# Elapsed time = 0.5680093765258789[s]
# homer_simpson_14.jpg
# []
# Elapsed time = 0.5731189250946045[s]
# homer_simpson_15.jpg
# []
# Elapsed time = 0.5651001930236816[s]
# homer_simpson_16.jpg
# []
# Elapsed time = 0.5836029052734375[s]
# homer_simpson_17.jpg
# []
# Elapsed time = 0.572213888168335[s]
# homer_simpson_18.jpg
# []
# Elapsed time = 0.6026787757873535[s]
# homer_simpson_19.jpg
# []
# Elapsed time = 0.5472607612609863[s]
# homer_simpson_2.jpg
# []
# Elapsed time = 0.6012434959411621[s]
# homer_simpson_20.jpg
# []
# Elapsed time = 0.6056947708129883[s]
# homer_simpson_21.jpg
# []
# Elapsed time = 0.5833697319030762[s]
# homer_simpson_22.jpg
# []
# Elapsed time = 0.579164981842041[s]
# homer_simpson_23.jpg
# []
# Elapsed time = 0.5865416526794434[s]
# homer_simpson_24.jpg
# []
# Elapsed time = 0.593743085861206[s]
# homer_simpson_25.jpg
# []
# Elapsed time = 0.5855879783630371[s]
# homer_simpson_26.jpg
# []
# Elapsed time = 0.5845658779144287[s]
# homer_simpson_27.jpg
# []
# Elapsed time = 0.5836083889007568[s]
# homer_simpson_28.jpg
# []
# Elapsed time = 0.5648055076599121[s]
# homer_simpson_29.jpg
# []
# Elapsed time = 0.5725216865539551[s]
# homer_simpson_3.jpg
# []
# Elapsed time = 0.583165168762207[s]
# homer_simpson_30.jpg
# []
# Elapsed time = 0.5800061225891113[s]
# homer_simpson_31.jpg
# []
# Elapsed time = 0.6050064563751221[s]
# homer_simpson_32.jpg
# []
# Elapsed time = 0.5815322399139404[s]
# homer_simpson_33.jpg
# []
# Elapsed time = 0.5702211856842041[s]
# homer_simpson_34.jpg
# []
# Elapsed time = 0.5888290405273438[s]
# homer_simpson_35.jpg
# []
# Elapsed time = 0.6002328395843506[s]
# homer_simpson_36.jpg
# []
# Elapsed time = 0.580042839050293[s]
# homer_simpson_37.jpg
# []
# Elapsed time = 0.5665574073791504[s]
# homer_simpson_38.jpg
# []
# Elapsed time = 0.5710208415985107[s]
# homer_simpson_39.jpg
# []
# Elapsed time = 0.5642714500427246[s]
# homer_simpson_4.jpg
# []
# Elapsed time = 0.5597481727600098[s]
# homer_simpson_40.jpg
# []
# Elapsed time = 0.6114370822906494[s]
# homer_simpson_41.jpg
# []
# Elapsed time = 0.5807650089263916[s]
# homer_simpson_42.jpg
# []
# Elapsed time = 0.5651140213012695[s]
# homer_simpson_43.jpg
# []
# Elapsed time = 0.5847845077514648[s]
# homer_simpson_44.jpg
# []
# Elapsed time = 0.5669689178466797[s]
# homer_simpson_45.jpg
# []
# Elapsed time = 0.6122009754180908[s]
# homer_simpson_46.jpg
# []
# Elapsed time = 0.5582175254821777[s]
# homer_simpson_47.jpg
# []
# Elapsed time = 0.5942907333374023[s]
# homer_simpson_48.jpg
# []
# Elapsed time = 0.5917131900787354[s]
# homer_simpson_49.jpg
# []
# Elapsed time = 0.5689280033111572[s]
# homer_simpson_5.jpg
# []
# Elapsed time = 0.5856940746307373[s]
# homer_simpson_6.jpg
# []
# Elapsed time = 0.5510506629943848[s]
# homer_simpson_7.jpg
# []
# Elapsed time = 0.6044266223907471[s]
# homer_simpson_8.jpg
# []
# Elapsed time = 0.5684330463409424[s]
# homer_simpson_9.jpg
# []
# Elapsed time = 0.5830621719360352[s]
# kent_brockman_0.jpg
# []
# Elapsed time = 0.5775108337402344[s]
# kent_brockman_1.jpg
# []
# Elapsed time = 0.7063043117523193[s]
# kent_brockman_10.jpg
# []
# Elapsed time = 0.5867164134979248[s]
# kent_brockman_11.jpg
# []
# Elapsed time = 0.5805044174194336[s]
# kent_brockman_12.jpg
# []
# Elapsed time = 0.5829694271087646[s]
# kent_brockman_13.jpg
# []
# Elapsed time = 0.5594594478607178[s]
# kent_brockman_14.jpg
# []
# Elapsed time = 0.589923620223999[s]
# kent_brockman_15.jpg
# []
# Elapsed time = 0.5836408138275146[s]
# kent_brockman_16.jpg
# []
# Elapsed time = 0.5740365982055664[s]
# kent_brockman_17.jpg
# []
# Elapsed time = 0.6050693988800049[s]
# kent_brockman_18.jpg
# []
# Elapsed time = 0.58341383934021[s]
# kent_brockman_19.jpg
# []
# Elapsed time = 0.5678596496582031[s]
# kent_brockman_2.jpg
# []
# Elapsed time = 0.5800044536590576[s]
# kent_brockman_20.jpg
# []
# Elapsed time = 0.5682709217071533[s]
# kent_brockman_21.jpg
# []
# Elapsed time = 0.6045727729797363[s]
# kent_brockman_22.jpg
# []
# Elapsed time = 0.5870645046234131[s]
# kent_brockman_23.jpg
# []
# Elapsed time = 0.5704984664916992[s]
# kent_brockman_24.jpg
# []
# Elapsed time = 0.5886645317077637[s]
# kent_brockman_25.jpg
# []
# Elapsed time = 0.6052370071411133[s]
# kent_brockman_26.jpg
# []
# Elapsed time = 0.811591625213623[s]
# kent_brockman_27.jpg
# []
# Elapsed time = 0.7630853652954102[s]
# kent_brockman_28.jpg
# []
# Elapsed time = 0.5839736461639404[s]
# kent_brockman_29.jpg
# []
# Elapsed time = 0.5782415866851807[s]
# kent_brockman_3.jpg
# []
# Elapsed time = 0.7354886531829834[s]
# kent_brockman_30.jpg
# []
# Elapsed time = 0.5954546928405762[s]
# kent_brockman_31.jpg
# []
# Elapsed time = 0.5953896045684814[s]
# kent_brockman_32.jpg
# []
# Elapsed time = 0.5869200229644775[s]
# kent_brockman_33.jpg
# []
# Elapsed time = 0.5710198879241943[s]
# kent_brockman_34.jpg
# []
# Elapsed time = 0.5615649223327637[s]
# kent_brockman_35.jpg
# []
# Elapsed time = 0.5836820602416992[s]
# kent_brockman_36.jpg
# []
# Elapsed time = 0.5600593090057373[s]
# kent_brockman_37.jpg
# []
# Elapsed time = 0.5808534622192383[s]
# kent_brockman_38.jpg
# []
# Elapsed time = 0.5650265216827393[s]
# kent_brockman_39.jpg
# []
# Elapsed time = 0.580857515335083[s]
# kent_brockman_4.jpg
# []
# Elapsed time = 0.5909104347229004[s]
# kent_brockman_40.jpg
# []
# Elapsed time = 0.5781221389770508[s]
# kent_brockman_41.jpg
# []
# Elapsed time = 0.579918622970581[s]
# kent_brockman_42.jpg
# []
# Elapsed time = 0.7056174278259277[s]
# kent_brockman_43.jpg
# []
# Elapsed time = 0.5848410129547119[s]
# kent_brockman_44.jpg
# []
# Elapsed time = 0.551239013671875[s]
# kent_brockman_45.jpg
# []
# Elapsed time = 0.5844619274139404[s]
# kent_brockman_46.jpg
# []
# Elapsed time = 0.570681095123291[s]
# kent_brockman_47.jpg
# []
# Elapsed time = 0.582005500793457[s]
# kent_brockman_48.jpg
# []
# Elapsed time = 0.5787124633789062[s]
# kent_brockman_49.jpg
# []
# Elapsed time = 0.7168984413146973[s]
# kent_brockman_5.jpg
# []
# Elapsed time = 0.5764093399047852[s]
# kent_brockman_6.jpg
# []
# Elapsed time = 0.6120955944061279[s]
# kent_brockman_7.jpg
# []
# Elapsed time = 0.5771472454071045[s]
# kent_brockman_8.jpg
# []
# Elapsed time = 0.6852767467498779[s]
# kent_brockman_9.jpg
# []
# Elapsed time = 0.5639920234680176[s]
# krusty_the_clown_0.jpg
# []
# Elapsed time = 0.5637030601501465[s]
# krusty_the_clown_1.jpg
# []
# Elapsed time = 0.6015036106109619[s]
# krusty_the_clown_10.jpg
# []
# Elapsed time = 0.6036477088928223[s]
# krusty_the_clown_11.jpg
# []
# Elapsed time = 0.5400776863098145[s]
# krusty_the_clown_12.jpg
# []
# Elapsed time = 0.5974161624908447[s]
# krusty_the_clown_13.jpg
# []
# Elapsed time = 0.5853450298309326[s]
# krusty_the_clown_14.jpg
# []
# Elapsed time = 0.5663583278656006[s]
# krusty_the_clown_15.jpg
# []
# Elapsed time = 0.5642142295837402[s]
# krusty_the_clown_16.jpg
# []
# Elapsed time = 0.587721586227417[s]
# krusty_the_clown_17.jpg
# []
# Elapsed time = 0.5842046737670898[s]
# krusty_the_clown_18.jpg
# []
# Elapsed time = 0.5742270946502686[s]
# krusty_the_clown_19.jpg
# []
# Elapsed time = 0.5936520099639893[s]
# krusty_the_clown_2.jpg
# []
# Elapsed time = 0.589508056640625[s]
# krusty_the_clown_20.jpg
# []
# Elapsed time = 0.5699725151062012[s]
# krusty_the_clown_21.jpg
# []
# Elapsed time = 0.5709578990936279[s]
# krusty_the_clown_22.jpg
# []
# Elapsed time = 0.5720045566558838[s]
# krusty_the_clown_23.jpg
# []
# Elapsed time = 0.599940299987793[s]
# krusty_the_clown_24.jpg
# []
# Elapsed time = 0.6326305866241455[s]
# krusty_the_clown_25.jpg
# []
# Elapsed time = 0.559502124786377[s]
# krusty_the_clown_26.jpg
# []
# Elapsed time = 0.6028544902801514[s]
# krusty_the_clown_27.jpg
# []
# Elapsed time = 0.5858645439147949[s]
# krusty_the_clown_28.jpg
# []
# Elapsed time = 0.5597133636474609[s]
# krusty_the_clown_29.jpg
# []
# Elapsed time = 0.5854237079620361[s]
# krusty_the_clown_3.jpg
# []
# Elapsed time = 0.5908477306365967[s]
# krusty_the_clown_30.jpg
# []
# Elapsed time = 0.5959963798522949[s]
# krusty_the_clown_31.jpg
# []
# Elapsed time = 0.5877490043640137[s]
# krusty_the_clown_32.jpg
# []
# Elapsed time = 0.5835661888122559[s]
# krusty_the_clown_33.jpg
# []
# Elapsed time = 0.5440187454223633[s]
# krusty_the_clown_34.jpg
# []
# Elapsed time = 0.6988160610198975[s]
# krusty_the_clown_35.jpg
# []
# Elapsed time = 0.5632796287536621[s]
# krusty_the_clown_36.jpg
# []
# Elapsed time = 0.5893690586090088[s]
# krusty_the_clown_37.jpg
# []
# Elapsed time = 0.5979001522064209[s]
# krusty_the_clown_38.jpg
# []
# Elapsed time = 0.5751738548278809[s]
# krusty_the_clown_39.jpg
# []
# Elapsed time = 0.6048586368560791[s]
# krusty_the_clown_4.jpg
# []
# Elapsed time = 0.5785329341888428[s]
# krusty_the_clown_40.jpg
# []
# Elapsed time = 0.6127989292144775[s]
# krusty_the_clown_41.jpg
# []
# Elapsed time = 0.5743527412414551[s]
# krusty_the_clown_42.jpg
# []
# Elapsed time = 0.5577199459075928[s]
# krusty_the_clown_43.jpg
# []
# Elapsed time = 0.547081708908081[s]
# krusty_the_clown_44.jpg
# []
# Elapsed time = 0.5616345405578613[s]
# krusty_the_clown_45.jpg
# []
# Elapsed time = 0.5682497024536133[s]
# krusty_the_clown_46.jpg
# []
# Elapsed time = 0.5575838088989258[s]
# krusty_the_clown_47.jpg
# []
# Elapsed time = 0.5820012092590332[s]
# krusty_the_clown_48.jpg
# []
# Elapsed time = 0.5965440273284912[s]
# krusty_the_clown_49.jpg
# []
# Elapsed time = 0.5841474533081055[s]
# krusty_the_clown_5.jpg
# []
# Elapsed time = 0.5981621742248535[s]
# krusty_the_clown_6.jpg
# []
# Elapsed time = 0.5803234577178955[s]
# krusty_the_clown_7.jpg
# []
# Elapsed time = 0.5943400859832764[s]
# krusty_the_clown_8.jpg
# []
# Elapsed time = 0.5542562007904053[s]
# krusty_the_clown_9.jpg
# []
# Elapsed time = 0.5982906818389893[s]
# lenny_leonard_0.jpg
# []
# Elapsed time = 0.5920124053955078[s]
# lenny_leonard_1.jpg
# []
# Elapsed time = 0.5708529949188232[s]
# lenny_leonard_10.jpg
# []
# Elapsed time = 0.5808374881744385[s]
# lenny_leonard_11.jpg
# []
# Elapsed time = 0.6038877964019775[s]
# lenny_leonard_12.jpg
# []
# Elapsed time = 0.5961692333221436[s]
# lenny_leonard_13.jpg
# []
# Elapsed time = 0.5910699367523193[s]
# lenny_leonard_14.jpg
# []
# Elapsed time = 0.6160175800323486[s]
# lenny_leonard_15.jpg
# []
# Elapsed time = 0.5800130367279053[s]
# lenny_leonard_16.jpg
# []
# Elapsed time = 0.5857870578765869[s]
# lenny_leonard_17.jpg
# []
# Elapsed time = 0.5587940216064453[s]
# lenny_leonard_18.jpg
# []
# Elapsed time = 0.5604350566864014[s]
# lenny_leonard_19.jpg
# []
# Elapsed time = 0.5948092937469482[s]
# lenny_leonard_2.jpg
# []
# Elapsed time = 0.5929896831512451[s]
# lenny_leonard_20.jpg
# []
# Elapsed time = 0.6053667068481445[s]
# lenny_leonard_21.jpg
# []
# Elapsed time = 0.5769252777099609[s]
# lenny_leonard_22.jpg
# []
# Elapsed time = 0.595954418182373[s]
# lenny_leonard_23.jpg
# []
# Elapsed time = 0.5899143218994141[s]
# lenny_leonard_24.jpg
# []
# Elapsed time = 0.5465612411499023[s]
# lenny_leonard_25.jpg
# []
# Elapsed time = 0.577815055847168[s]
# lenny_leonard_26.jpg
# []
# Elapsed time = 0.5796053409576416[s]
# lenny_leonard_27.jpg
# []
# Elapsed time = 0.5883643627166748[s]
# lenny_leonard_28.jpg
# []
# Elapsed time = 0.5722918510437012[s]
# lenny_leonard_29.jpg
# []
# Elapsed time = 0.5848991870880127[s]
# lenny_leonard_3.jpg
# []
# Elapsed time = 0.5647497177124023[s]
# lenny_leonard_30.jpg
# []
# Elapsed time = 0.5977857112884521[s]
# lenny_leonard_31.jpg
# []
# Elapsed time = 0.7702641487121582[s]
# lenny_leonard_32.jpg
# []
# Elapsed time = 0.5883958339691162[s]
# lenny_leonard_33.jpg
# []
# Elapsed time = 0.5880551338195801[s]
# lenny_leonard_34.jpg
# []
# Elapsed time = 0.5894904136657715[s]
# lenny_leonard_35.jpg
# []
# Elapsed time = 0.5671372413635254[s]
# lenny_leonard_36.jpg
# []
# Elapsed time = 0.5714828968048096[s]
# lenny_leonard_37.jpg
# []
# Elapsed time = 0.6118981838226318[s]
# lenny_leonard_38.jpg
# []
# Elapsed time = 0.5916798114776611[s]
# lenny_leonard_39.jpg
# []
# Elapsed time = 0.563279390335083[s]
# lenny_leonard_4.jpg
# []
# Elapsed time = 0.6062619686126709[s]
# lenny_leonard_40.jpg
# []
# Elapsed time = 0.6044540405273438[s]
# lenny_leonard_41.jpg
# []
# Elapsed time = 0.5627686977386475[s]
# lenny_leonard_42.jpg
# []
# Elapsed time = 0.5630898475646973[s]
# lenny_leonard_43.jpg
# []
# Elapsed time = 0.5975284576416016[s]
# lenny_leonard_44.jpg
# []
# Elapsed time = 0.5597538948059082[s]
# lenny_leonard_45.jpg
# []
# Elapsed time = 0.5796248912811279[s]
# lenny_leonard_46.jpg
# []
# Elapsed time = 0.5881049633026123[s]
# lenny_leonard_47.jpg
# []
# Elapsed time = 0.5744752883911133[s]
# lenny_leonard_48.jpg
# []
# Elapsed time = 0.5888452529907227[s]
# lenny_leonard_49.jpg
# []
# Elapsed time = 0.6090085506439209[s]
# lenny_leonard_5.jpg
# []
# Elapsed time = 0.5793900489807129[s]
# lenny_leonard_6.jpg
# []
# Elapsed time = 0.9386935234069824[s]
# lenny_leonard_7.jpg
# []
# Elapsed time = 0.5401899814605713[s]
# lenny_leonard_8.jpg
# []
# Elapsed time = 0.5756645202636719[s]
# lenny_leonard_9.jpg
# []
# Elapsed time = 0.6191787719726562[s]
# lisa_simpson_0.jpg
# []
# Elapsed time = 0.5424902439117432[s]
# lisa_simpson_1.jpg
# []
# Elapsed time = 0.5633869171142578[s]
# lisa_simpson_10.jpg
# []
# Elapsed time = 0.5663831233978271[s]
# lisa_simpson_11.jpg
# []
# Elapsed time = 0.5710206031799316[s]
# lisa_simpson_12.jpg
# []
# Elapsed time = 0.5777993202209473[s]
# lisa_simpson_13.jpg
# []
# Elapsed time = 0.5814461708068848[s]
# lisa_simpson_14.jpg
# []
# Elapsed time = 0.5898122787475586[s]
# lisa_simpson_15.jpg
# []
# Elapsed time = 0.5934734344482422[s]
# lisa_simpson_16.jpg
# []
# Elapsed time = 0.5746941566467285[s]
# lisa_simpson_17.jpg
# []
# Elapsed time = 0.5853543281555176[s]
# lisa_simpson_18.jpg
# []
# Elapsed time = 0.5873329639434814[s]
# lisa_simpson_19.jpg
# []
# Elapsed time = 0.6052567958831787[s]
# lisa_simpson_2.jpg
# []
# Elapsed time = 0.5944178104400635[s]
# lisa_simpson_20.jpg
# []
# Elapsed time = 0.558887243270874[s]
# lisa_simpson_21.jpg
# []
# Elapsed time = 0.6004197597503662[s]
# lisa_simpson_22.jpg
# []
# Elapsed time = 0.542611837387085[s]
# lisa_simpson_23.jpg
# []
# Elapsed time = 0.5868983268737793[s]
# lisa_simpson_24.jpg
# []
# Elapsed time = 0.5694794654846191[s]
# lisa_simpson_25.jpg
# []
# Elapsed time = 0.5767645835876465[s]
# lisa_simpson_26.jpg
# []
# Elapsed time = 0.574131965637207[s]
# lisa_simpson_27.jpg
# []
# Elapsed time = 0.5692300796508789[s]
# lisa_simpson_28.jpg
# []
# Elapsed time = 0.6021461486816406[s]
# lisa_simpson_29.jpg
# []
# Elapsed time = 0.5779669284820557[s]
# lisa_simpson_3.jpg
# []
# Elapsed time = 0.5775275230407715[s]
# lisa_simpson_30.jpg
# []
# Elapsed time = 0.6007916927337646[s]
# lisa_simpson_31.jpg
# []
# Elapsed time = 0.6106431484222412[s]
# lisa_simpson_32.jpg
# []
# Elapsed time = 0.5874197483062744[s]
# lisa_simpson_33.jpg
# []
# Elapsed time = 0.6021318435668945[s]
# lisa_simpson_34.jpg
# []
# Elapsed time = 0.5842239856719971[s]
# lisa_simpson_35.jpg
# []
# Elapsed time = 0.5625107288360596[s]
# lisa_simpson_36.jpg
# []
# Elapsed time = 0.5870945453643799[s]
# lisa_simpson_37.jpg
# []
# Elapsed time = 0.5843439102172852[s]
# lisa_simpson_38.jpg
# []
# Elapsed time = 0.5924322605133057[s]
# lisa_simpson_39.jpg
# []
# Elapsed time = 0.5391170978546143[s]
# lisa_simpson_4.jpg
# []
# Elapsed time = 0.5775089263916016[s]
# lisa_simpson_40.jpg
# []
# Elapsed time = 0.6039505004882812[s]
# lisa_simpson_41.jpg
# []
# Elapsed time = 0.5972201824188232[s]
# lisa_simpson_42.jpg
# []
# Elapsed time = 0.5749123096466064[s]
# lisa_simpson_43.jpg
# []
# Elapsed time = 0.5873439311981201[s]
# lisa_simpson_44.jpg
# []
# Elapsed time = 0.5957450866699219[s]
# lisa_simpson_45.jpg
# []
# Elapsed time = 0.5991733074188232[s]
# lisa_simpson_46.jpg
# []
# Elapsed time = 0.5923686027526855[s]
# lisa_simpson_47.jpg
# []
# Elapsed time = 0.5878994464874268[s]
# lisa_simpson_48.jpg
# []
# Elapsed time = 0.5950930118560791[s]
# lisa_simpson_49.jpg
# []
# Elapsed time = 0.5895547866821289[s]
# lisa_simpson_5.jpg
# []
# Elapsed time = 0.5271718502044678[s]
# lisa_simpson_6.jpg
# []
# Elapsed time = 0.5923991203308105[s]
# lisa_simpson_7.jpg
# []
# Elapsed time = 0.5841467380523682[s]
# lisa_simpson_8.jpg
# []
# Elapsed time = 0.6031811237335205[s]
# lisa_simpson_9.jpg
# []
# Elapsed time = 0.5915281772613525[s]
# marge_simpson_0.jpg
# []
# Elapsed time = 0.61319899559021[s]
# marge_simpson_1.jpg
# []
# Elapsed time = 0.599703311920166[s]
# marge_simpson_10.jpg
# []
# Elapsed time = 0.5669758319854736[s]
# marge_simpson_11.jpg
# []
# Elapsed time = 0.5831220149993896[s]
# marge_simpson_12.jpg
# []
# Elapsed time = 0.5722386837005615[s]
# marge_simpson_13.jpg
# []
# Elapsed time = 0.5782485008239746[s]
# marge_simpson_14.jpg
# []
# Elapsed time = 0.5956346988677979[s]
# marge_simpson_15.jpg
# []
# Elapsed time = 0.5912089347839355[s]
# marge_simpson_16.jpg
# []
# Elapsed time = 0.5481321811676025[s]
# marge_simpson_17.jpg
# []
# Elapsed time = 0.5601439476013184[s]
# marge_simpson_18.jpg
# []
# Elapsed time = 0.5838563442230225[s]
# marge_simpson_19.jpg
# []
# Elapsed time = 0.5802686214447021[s]
# marge_simpson_2.jpg
# []
# Elapsed time = 0.5900182723999023[s]
# marge_simpson_20.jpg
# []
# Elapsed time = 0.5951647758483887[s]
# marge_simpson_21.jpg
# []
# Elapsed time = 0.5894525051116943[s]
# marge_simpson_22.jpg
# []
# Elapsed time = 0.6065042018890381[s]
# marge_simpson_23.jpg
# []
# Elapsed time = 0.5792088508605957[s]
# marge_simpson_24.jpg
# []
# Elapsed time = 0.5859348773956299[s]
# marge_simpson_25.jpg
# []
# Elapsed time = 0.5990359783172607[s]
# marge_simpson_26.jpg
# []
# Elapsed time = 0.5917329788208008[s]
# marge_simpson_27.jpg
# []
# Elapsed time = 0.5922055244445801[s]
# marge_simpson_28.jpg
# []
# Elapsed time = 0.5935964584350586[s]
# marge_simpson_29.jpg
# []
# Elapsed time = 0.5959596633911133[s]
# marge_simpson_3.jpg
# []
# Elapsed time = 0.5842525959014893[s]
# marge_simpson_30.jpg
# []
# Elapsed time = 0.5424938201904297[s]
# marge_simpson_31.jpg
# []
# Elapsed time = 0.572145938873291[s]
# marge_simpson_32.jpg
# []
# Elapsed time = 0.6027548313140869[s]
# marge_simpson_33.jpg
# []
# Elapsed time = 0.6077253818511963[s]
# marge_simpson_34.jpg
# []
# Elapsed time = 0.6032629013061523[s]
# marge_simpson_35.jpg
# []
# Elapsed time = 0.6027095317840576[s]
# marge_simpson_36.jpg
# []
# Elapsed time = 0.5833804607391357[s]
# marge_simpson_37.jpg
# []
# Elapsed time = 0.5992357730865479[s]
# marge_simpson_38.jpg
# []
# Elapsed time = 0.5649394989013672[s]
# marge_simpson_39.jpg
# []
# Elapsed time = 0.6214096546173096[s]
# marge_simpson_4.jpg
# []
# Elapsed time = 0.5693061351776123[s]
# marge_simpson_40.jpg
# []
# Elapsed time = 0.5892302989959717[s]
# marge_simpson_41.jpg
# []
# Elapsed time = 0.6124715805053711[s]
# marge_simpson_42.jpg
# []
# Elapsed time = 0.5864369869232178[s]
# marge_simpson_43.jpg
# []
# Elapsed time = 0.5847620964050293[s]
# marge_simpson_44.jpg
# []
# Elapsed time = 0.5925679206848145[s]
# marge_simpson_45.jpg
# []
# Elapsed time = 0.5915756225585938[s]
# marge_simpson_46.jpg
# []
# Elapsed time = 0.5969457626342773[s]
# marge_simpson_47.jpg
# []
# Elapsed time = 0.5758140087127686[s]
# marge_simpson_48.jpg
# []
# ...
# []
# Elapsed time = 0.5829813480377197[s]
# milhouse_van_houten_4.jpg
# []
# Elapsed time = 0.5762755870819092[s]
# milhouse_van_houten_40.jpg
# []
# Elapsed time = 0.5739614963531494[s]
# milhouse_van_houten_41.jpg
# []
# Elapsed time = 0.5787715911865234[s]
# milhouse_van_houten_42.jpg
# []
# Elapsed time = 0.6118123531341553[s]
# milhouse_van_houten_43.jpg
# []
# Elapsed time = 0.5880212783813477[s]
# milhouse_van_houten_44.jpg
# []
# Elapsed time = 0.6079084873199463[s]
# milhouse_van_houten_45.jpg
# []
# Elapsed time = 0.5893247127532959[s]
# milhouse_van_houten_46.jpg
# []
# Elapsed time = 0.6069958209991455[s]
# milhouse_van_houten_47.jpg
# []
# Elapsed time = 0.5769205093383789[s]
# milhouse_van_houten_48.jpg
# []
# Elapsed time = 0.7236428260803223[s]
# milhouse_van_houten_49.jpg
# []
# Elapsed time = 0.5647218227386475[s]
# milhouse_van_houten_5.jpg
# []
# Elapsed time = 0.6044859886169434[s]
# milhouse_van_houten_6.jpg
# []
# Elapsed time = 0.5981423854827881[s]
# milhouse_van_houten_7.jpg
# []
# Elapsed time = 0.5945751667022705[s]
# milhouse_van_houten_8.jpg
# []
# Elapsed time = 0.5920374393463135[s]
# milhouse_van_houten_9.jpg
# []
# Elapsed time = 0.6140449047088623[s]
# moe_szyslak_0.jpg
# []
# Elapsed time = 0.5398223400115967[s]
# moe_szyslak_1.jpg
# []
# Elapsed time = 0.758223295211792[s]
# moe_szyslak_10.jpg
# []
# Elapsed time = 0.5397391319274902[s]
# moe_szyslak_11.jpg
# []
# Elapsed time = 0.5820925235748291[s]
# moe_szyslak_12.jpg
# []
# Elapsed time = 0.5783746242523193[s]
# moe_szyslak_13.jpg
# []
# Elapsed time = 0.7118234634399414[s]
# moe_szyslak_14.jpg
# []
# Elapsed time = 0.6083533763885498[s]
# moe_szyslak_15.jpg
# []
# Elapsed time = 0.5893814563751221[s]
# moe_szyslak_16.jpg
# []
# Elapsed time = 0.5923328399658203[s]
# moe_szyslak_17.jpg
# []
# Elapsed time = 0.5637967586517334[s]
# moe_szyslak_18.jpg
# []
# Elapsed time = 0.5634753704071045[s]
# moe_szyslak_19.jpg
# []
# Elapsed time = 0.5624189376831055[s]
# moe_szyslak_2.jpg
# []
# Elapsed time = 0.597357988357544[s]
# moe_szyslak_20.jpg
# []
# Elapsed time = 0.5814690589904785[s]
# moe_szyslak_21.jpg
# []
# Elapsed time = 0.5743236541748047[s]
# moe_szyslak_22.jpg
# []
# Elapsed time = 0.5845446586608887[s]
# moe_szyslak_23.jpg
# []
# Elapsed time = 0.6904728412628174[s]
# moe_szyslak_24.jpg
# []
# Elapsed time = 0.5920929908752441[s]
# moe_szyslak_25.jpg
# []
# Elapsed time = 0.5734732151031494[s]
# moe_szyslak_26.jpg
# []
# Elapsed time = 0.589226484298706[s]
# moe_szyslak_27.jpg
# []
# Elapsed time = 0.5847673416137695[s]
# moe_szyslak_28.jpg
# []
# Elapsed time = 0.5435864925384521[s]
# moe_szyslak_29.jpg
# []
# Elapsed time = 0.583235502243042[s]
# moe_szyslak_3.jpg
# []
# Elapsed time = 0.5681231021881104[s]
# moe_szyslak_30.jpg
# []
# Elapsed time = 0.5828828811645508[s]
# moe_szyslak_31.jpg
# []
# Elapsed time = 0.577662467956543[s]
# moe_szyslak_32.jpg
# []
# Elapsed time = 0.5819694995880127[s]
# moe_szyslak_33.jpg
# []
# Elapsed time = 0.5780651569366455[s]
# moe_szyslak_34.jpg
# []
# Elapsed time = 0.5660016536712646[s]
# moe_szyslak_35.jpg
# []
# Elapsed time = 0.5721447467803955[s]
# moe_szyslak_36.jpg
# []
# Elapsed time = 0.534430980682373[s]
# moe_szyslak_37.jpg
# []
# Elapsed time = 0.5850882530212402[s]
# moe_szyslak_38.jpg
# []
# Elapsed time = 0.5919992923736572[s]
# moe_szyslak_39.jpg
# []
# Elapsed time = 0.5871152877807617[s]
# moe_szyslak_4.jpg
# []
# Elapsed time = 0.5659172534942627[s]
# moe_szyslak_40.jpg
# []
# Elapsed time = 0.5412585735321045[s]
# moe_szyslak_41.jpg
# []
# Elapsed time = 0.5544521808624268[s]
# moe_szyslak_42.jpg
# []
# Elapsed time = 0.5816559791564941[s]
# moe_szyslak_43.jpg
# []
# Elapsed time = 0.5851128101348877[s]
# moe_szyslak_44.jpg
# []
# Elapsed time = 0.5573601722717285[s]
# moe_szyslak_45.jpg
# []
# Elapsed time = 0.5370728969573975[s]
# moe_szyslak_46.jpg
# []
# Elapsed time = 0.5708014965057373[s]
# moe_szyslak_47.jpg
# []
# Elapsed time = 0.5883808135986328[s]
# moe_szyslak_48.jpg
# []
# Elapsed time = 0.5534191131591797[s]
# moe_szyslak_49.jpg
# []
# Elapsed time = 0.5421168804168701[s]
# moe_szyslak_5.jpg
# []
# Elapsed time = 0.5858352184295654[s]
# moe_szyslak_6.jpg
# []
# Elapsed time = 0.5514817237854004[s]
# moe_szyslak_7.jpg
# []
# Elapsed time = 0.6665596961975098[s]
# moe_szyslak_8.jpg
# []
# Elapsed time = 0.5600905418395996[s]
# moe_szyslak_9.jpg
# []
# Elapsed time = 0.6263666152954102[s]
# ned_flanders_0.jpg
# []
# Elapsed time = 0.5864343643188477[s]
# ned_flanders_1.jpg
# []
# Elapsed time = 0.5680437088012695[s]
# ned_flanders_10.jpg
# []
# Elapsed time = 0.5790235996246338[s]
# ned_flanders_11.jpg
# []
# Elapsed time = 0.5708391666412354[s]
# ned_flanders_12.jpg
# []
# Elapsed time = 0.5880515575408936[s]
# ned_flanders_13.jpg
# []
# Elapsed time = 0.5459275245666504[s]
# ned_flanders_14.jpg
# []
# Elapsed time = 0.5984756946563721[s]
# ned_flanders_15.jpg
# []
# Elapsed time = 0.5755023956298828[s]
# ned_flanders_16.jpg
# []
# Elapsed time = 0.5714690685272217[s]
# ned_flanders_17.jpg
# []
# Elapsed time = 0.5566461086273193[s]
# ned_flanders_18.jpg
# []
# Elapsed time = 0.541715145111084[s]
# ned_flanders_19.jpg
# []
# Elapsed time = 0.5904548168182373[s]
# ned_flanders_2.jpg
# []
# Elapsed time = 0.5443177223205566[s]
# ned_flanders_20.jpg
# []
# Elapsed time = 0.5787820816040039[s]
# ned_flanders_21.jpg
# []
# Elapsed time = 0.5805618762969971[s]
# ned_flanders_22.jpg
# []
# Elapsed time = 0.5401115417480469[s]
# ned_flanders_23.jpg
# []
# Elapsed time = 0.6024296283721924[s]
# ned_flanders_24.jpg
# []
# Elapsed time = 0.605858325958252[s]
# ned_flanders_25.jpg
# []
# Elapsed time = 0.5622918605804443[s]
# ned_flanders_26.jpg
# []
# Elapsed time = 0.5672669410705566[s]
# ned_flanders_27.jpg
# []
# Elapsed time = 0.570645809173584[s]
# ned_flanders_28.jpg
# []
# Elapsed time = 0.5839979648590088[s]
# ned_flanders_29.jpg
# []
# Elapsed time = 0.5626401901245117[s]
# ned_flanders_3.jpg
# []
# Elapsed time = 0.5911352634429932[s]
# ned_flanders_30.jpg
# []
# Elapsed time = 0.5461692810058594[s]
# ned_flanders_31.jpg
# []
# Elapsed time = 0.5832898616790771[s]
# ned_flanders_32.jpg
# []
# Elapsed time = 0.5774755477905273[s]
# ned_flanders_33.jpg
# []
# Elapsed time = 0.577193021774292[s]
# ned_flanders_34.jpg
# []
# Elapsed time = 0.567962646484375[s]
# ned_flanders_35.jpg
# []
# Elapsed time = 0.5754859447479248[s]
# ned_flanders_36.jpg
# []
# Elapsed time = 0.5345666408538818[s]
# ned_flanders_37.jpg
# []
# Elapsed time = 0.7648670673370361[s]
# ned_flanders_38.jpg
# []
# Elapsed time = 0.5438575744628906[s]
# ned_flanders_39.jpg
# []
# Elapsed time = 0.6057145595550537[s]
# ned_flanders_4.jpg
# []
# Elapsed time = 0.59425950050354[s]
# ned_flanders_40.jpg
# []
# Elapsed time = 0.535851001739502[s]
# ned_flanders_41.jpg
# []
# Elapsed time = 0.5753240585327148[s]
# ned_flanders_42.jpg
# []
# Elapsed time = 0.5825295448303223[s]
# ned_flanders_43.jpg
# []
# Elapsed time = 0.5729684829711914[s]
# ned_flanders_44.jpg
# []
# Elapsed time = 0.5465133190155029[s]
# ned_flanders_46.jpg
# []
# Elapsed time = 0.6147947311401367[s]
# ned_flanders_47.jpg
# []
# Elapsed time = 0.5655322074890137[s]
# ned_flanders_48.jpg
# []
# Elapsed time = 0.562915563583374[s]
# ned_flanders_49.jpg
# []
# Elapsed time = 0.5381503105163574[s]
# ned_flanders_5.jpg
# []
# Elapsed time = 0.5762882232666016[s]
# ned_flanders_6.jpg
# []
# Elapsed time = 0.5754284858703613[s]
# ned_flanders_7.jpg
# []
# Elapsed time = 0.5781564712524414[s]
# ned_flanders_8.jpg
# []
# Elapsed time = 0.5759072303771973[s]
# ned_flanders_9.jpg
# []
# Elapsed time = 0.6122984886169434[s]
# nelson_muntz_0.jpg
# []
# Elapsed time = 0.6096165180206299[s]
# nelson_muntz_1.jpg
# []
# Elapsed time = 0.5376396179199219[s]
# nelson_muntz_10.jpg
# []
# Elapsed time = 0.5593807697296143[s]
# nelson_muntz_11.jpg
# []
# Elapsed time = 0.538001298904419[s]
# nelson_muntz_12.jpg
# []
# Elapsed time = 0.5541491508483887[s]
# nelson_muntz_13.jpg
# []
# Elapsed time = 0.6066200733184814[s]
# nelson_muntz_14.jpg
# []
# Elapsed time = 0.5790612697601318[s]
# nelson_muntz_15.jpg
# []
# Elapsed time = 0.550100564956665[s]
# nelson_muntz_16.jpg
# []
# Elapsed time = 0.5352532863616943[s]
# nelson_muntz_17.jpg
# []
# Elapsed time = 0.5436530113220215[s]
# nelson_muntz_18.jpg
# []
# Elapsed time = 0.5883150100708008[s]
# nelson_muntz_19.jpg
# []
# Elapsed time = 0.5680074691772461[s]
# nelson_muntz_2.jpg
# []
# Elapsed time = 0.5815637111663818[s]
# nelson_muntz_20.jpg
# []
# Elapsed time = 0.5613863468170166[s]
# nelson_muntz_21.jpg
# []
# Elapsed time = 0.5802786350250244[s]
# nelson_muntz_22.jpg
# []
# Elapsed time = 0.5540404319763184[s]
# nelson_muntz_23.jpg
# []
# Elapsed time = 0.5351250171661377[s]
# nelson_muntz_24.jpg
# []
# Elapsed time = 0.6064307689666748[s]
# nelson_muntz_25.jpg
# []
# Elapsed time = 0.5678560733795166[s]
# nelson_muntz_26.jpg
# []
# Elapsed time = 0.5706465244293213[s]
# nelson_muntz_27.jpg
# []
# Elapsed time = 0.589360237121582[s]
# nelson_muntz_28.jpg
# []
# Elapsed time = 0.5472455024719238[s]
# nelson_muntz_29.jpg
# []
# Elapsed time = 0.5418751239776611[s]
# nelson_muntz_3.jpg
# []
# Elapsed time = 0.5514547824859619[s]
# nelson_muntz_30.jpg
# []
# Elapsed time = 0.5605418682098389[s]
# nelson_muntz_31.jpg
# []
# Elapsed time = 0.5897743701934814[s]
# nelson_muntz_32.jpg
# []
# Elapsed time = 0.5700700283050537[s]
# nelson_muntz_33.jpg
# []
# Elapsed time = 0.5641040802001953[s]
# nelson_muntz_34.jpg
# []
# Elapsed time = 0.5995781421661377[s]
# nelson_muntz_35.jpg
# []
# Elapsed time = 0.6099319458007812[s]
# nelson_muntz_36.jpg
# []
# Elapsed time = 0.5650444030761719[s]
# nelson_muntz_37.jpg
# []
# Elapsed time = 0.5881717205047607[s]
# nelson_muntz_38.jpg
# []
# Elapsed time = 0.5365040302276611[s]
# nelson_muntz_39.jpg
# []
# Elapsed time = 0.578427791595459[s]
# nelson_muntz_4.jpg
# []
# Elapsed time = 0.5396790504455566[s]
# nelson_muntz_40.jpg
# []
# Elapsed time = 0.5896933078765869[s]
# nelson_muntz_41.jpg
# []
# Elapsed time = 0.5993640422821045[s]
# nelson_muntz_42.jpg
# []
# Elapsed time = 0.6298294067382812[s]
# nelson_muntz_43.jpg
# []
# Elapsed time = 0.5767631530761719[s]
# nelson_muntz_44.jpg
# []
# Elapsed time = 0.5738143920898438[s]
# nelson_muntz_45.jpg
# []
# Elapsed time = 0.5548446178436279[s]
# nelson_muntz_46.jpg
# []
# Elapsed time = 0.5780794620513916[s]
# nelson_muntz_47.jpg
# []
# Elapsed time = 0.5317070484161377[s]
# nelson_muntz_48.jpg
# []
# Elapsed time = 0.5412397384643555[s]
# nelson_muntz_49.jpg
# []
# Elapsed time = 0.6061816215515137[s]
# nelson_muntz_5.jpg
# []
# Elapsed time = 0.6524291038513184[s]
# nelson_muntz_6.jpg
# []
# Elapsed time = 0.5817735195159912[s]
# nelson_muntz_7.jpg
# []
# Elapsed time = 0.598499059677124[s]
# nelson_muntz_8.jpg
# []
# Elapsed time = 0.5952138900756836[s]
# nelson_muntz_9.jpg
# []
# Elapsed time = 0.5457401275634766[s]
# principal_skinner_0.jpg
# []
# Elapsed time = 0.6210658550262451[s]
# principal_skinner_1.jpg
# []
# Elapsed time = 0.582338809967041[s]
# principal_skinner_10.jpg
# []
# Elapsed time = 0.6110007762908936[s]
# principal_skinner_11.jpg
# []
# Elapsed time = 0.5899171829223633[s]
# principal_skinner_12.jpg
# []
# Elapsed time = 0.6717848777770996[s]
# principal_skinner_13.jpg
# []
# Elapsed time = 0.5901038646697998[s]
# principal_skinner_14.jpg
# []
# Elapsed time = 0.5881776809692383[s]
# principal_skinner_15.jpg
# []
# Elapsed time = 0.5690903663635254[s]
# principal_skinner_16.jpg
# []
# Elapsed time = 0.5675287246704102[s]
# principal_skinner_17.jpg
# []
# Elapsed time = 0.5713179111480713[s]
# principal_skinner_18.jpg
# []
# Elapsed time = 0.6004512310028076[s]
# principal_skinner_19.jpg
# []
# Elapsed time = 0.5775902271270752[s]
# principal_skinner_2.jpg
# []
# Elapsed time = 0.5751738548278809[s]
# principal_skinner_20.jpg
# []
# Elapsed time = 0.5889220237731934[s]
# principal_skinner_21.jpg
# []
# Elapsed time = 0.5642220973968506[s]
# principal_skinner_22.jpg
# []
# Elapsed time = 0.5471701622009277[s]
# principal_skinner_23.jpg
# []
# Elapsed time = 0.5829792022705078[s]
# principal_skinner_24.jpg
# []
# Elapsed time = 0.5551736354827881[s]
# principal_skinner_25.jpg
# []
# Elapsed time = 0.5778377056121826[s]
# principal_skinner_26.jpg
# []
# Elapsed time = 0.5727403163909912[s]
# principal_skinner_27.jpg
# []
# Elapsed time = 0.5881330966949463[s]
# principal_skinner_28.jpg
# []
# Elapsed time = 0.5915889739990234[s]
# principal_skinner_29.jpg
# []
# Elapsed time = 0.5717148780822754[s]
# principal_skinner_3.jpg
# []
# Elapsed time = 0.5465681552886963[s]
# principal_skinner_30.jpg
# []
# Elapsed time = 0.5861396789550781[s]
# principal_skinner_31.jpg
# []
# Elapsed time = 0.5814304351806641[s]
# principal_skinner_32.jpg
# []
# Elapsed time = 0.5767948627471924[s]
# principal_skinner_33.jpg
# []
# Elapsed time = 0.5792727470397949[s]
# principal_skinner_34.jpg
# []
# Elapsed time = 0.5840728282928467[s]
# principal_skinner_35.jpg
# []
# Elapsed time = 0.5838437080383301[s]
# principal_skinner_36.jpg
# []
# Elapsed time = 0.6080634593963623[s]
# principal_skinner_37.jpg
# []
# Elapsed time = 0.562387228012085[s]
# principal_skinner_38.jpg
# []
# Elapsed time = 0.590339183807373[s]
# principal_skinner_39.jpg
# []
# Elapsed time = 0.5789146423339844[s]
# principal_skinner_4.jpg
# []
# Elapsed time = 0.5801312923431396[s]
# principal_skinner_40.jpg
# []
# Elapsed time = 0.5457658767700195[s]
# principal_skinner_41.jpg
# []
# Elapsed time = 0.5687274932861328[s]
# principal_skinner_42.jpg
# []
# Elapsed time = 0.5722556114196777[s]
# principal_skinner_43.jpg
# []
# Elapsed time = 0.5659811496734619[s]
# principal_skinner_44.jpg
# []
# Elapsed time = 0.6074519157409668[s]
# principal_skinner_45.jpg
# []
# Elapsed time = 0.5770416259765625[s]
# principal_skinner_46.jpg
# []
# Elapsed time = 0.575164794921875[s]
# principal_skinner_47.jpg
# []
# Elapsed time = 0.6967971324920654[s]
# principal_skinner_48.jpg
# []
# Elapsed time = 0.5698707103729248[s]
# principal_skinner_49.jpg
# []
# Elapsed time = 0.5419535636901855[s]
# principal_skinner_5.jpg
# []
# Elapsed time = 0.575308084487915[s]
# principal_skinner_6.jpg
# []
# Elapsed time = 0.5741963386535645[s]
# principal_skinner_7.jpg
# []
# Elapsed time = 0.5861127376556396[s]
# principal_skinner_8.jpg
# []
# Elapsed time = 0.58487868309021[s]
# principal_skinner_9.jpg
# []
# Elapsed time = 0.586172342300415[s]
# sideshow_bob_0.jpg
# []
# Elapsed time = 0.5979130268096924[s]
# sideshow_bob_1.jpg
# []
# Elapsed time = 0.592970609664917[s]
# sideshow_bob_10.jpg
# []
# Elapsed time = 0.5856115818023682[s]
# sideshow_bob_11.jpg
# []
# Elapsed time = 0.579322099685669[s]
# sideshow_bob_12.jpg
# []
# Elapsed time = 0.5822999477386475[s]
# sideshow_bob_13.jpg
# []
# Elapsed time = 0.582054853439331[s]
# sideshow_bob_14.jpg
# []
# Elapsed time = 0.6107034683227539[s]
# sideshow_bob_15.jpg
# []
# Elapsed time = 0.5936183929443359[s]
# sideshow_bob_16.jpg
# []
# Elapsed time = 0.5772097110748291[s]
# sideshow_bob_17.jpg
# []
# Elapsed time = 0.5947434902191162[s]
# sideshow_bob_18.jpg
# []
# Elapsed time = 0.5784940719604492[s]
# sideshow_bob_19.jpg
# []
# Elapsed time = 0.564255952835083[s]
# sideshow_bob_2.jpg
# []
# Elapsed time = 0.611994743347168[s]
# sideshow_bob_20.jpg
# []
# Elapsed time = 0.669020414352417[s]
# sideshow_bob_21.jpg
# []
# Elapsed time = 0.5662238597869873[s]
# sideshow_bob_22.jpg
# []
# Elapsed time = 0.5648128986358643[s]
# sideshow_bob_23.jpg
# []
# Elapsed time = 0.5726368427276611[s]
# sideshow_bob_24.jpg
# []
# Elapsed time = 0.5603187084197998[s]
# sideshow_bob_25.jpg
# []
# Elapsed time = 0.6109225749969482[s]
# sideshow_bob_26.jpg
# []
# Elapsed time = 0.5672216415405273[s]
# sideshow_bob_27.jpg
# []
# Elapsed time = 0.5893678665161133[s]
# sideshow_bob_28.jpg
# []
# Elapsed time = 0.5882575511932373[s]
# sideshow_bob_29.jpg
# []
# Elapsed time = 0.5781681537628174[s]
# sideshow_bob_3.jpg
# []
# Elapsed time = 0.5886077880859375[s]
# sideshow_bob_30.jpg
# []
# Elapsed time = 0.5731215476989746[s]
# sideshow_bob_31.jpg
# []
# Elapsed time = 0.7556540966033936[s]
# sideshow_bob_32.jpg
# []
# Elapsed time = 0.5862245559692383[s]
# sideshow_bob_33.jpg
# []
# Elapsed time = 0.5606372356414795[s]
# sideshow_bob_34.jpg
# []
# Elapsed time = 0.5939998626708984[s]
# sideshow_bob_36.jpg
# []
# Elapsed time = 0.5944247245788574[s]
# sideshow_bob_37.jpg
# []
# Elapsed time = 0.566577672958374[s]
# sideshow_bob_38.jpg
# []
# Elapsed time = 0.5801255702972412[s]
# sideshow_bob_39.jpg
# []
# Elapsed time = 0.5692939758300781[s]
# sideshow_bob_4.jpg
# []
# Elapsed time = 0.5860292911529541[s]
# sideshow_bob_40.jpg
# []
# Elapsed time = 0.5587377548217773[s]
# sideshow_bob_41.jpg
# []
# Elapsed time = 0.5844671726226807[s]
# sideshow_bob_42.jpg
# []
# Elapsed time = 0.5903806686401367[s]
# sideshow_bob_43.jpg
# []
# Elapsed time = 0.5558280944824219[s]
# sideshow_bob_44.jpg
# []
# Elapsed time = 0.5787453651428223[s]
# sideshow_bob_45.jpg
# []
# Elapsed time = 0.5858967304229736[s]
# sideshow_bob_47.jpg
# []
# Elapsed time = 0.5650320053100586[s]
# sideshow_bob_48.jpg
# []
# Elapsed time = 0.5806052684783936[s]
# sideshow_bob_49.jpg
# []
# Elapsed time = 0.57537841796875[s]
# sideshow_bob_5.jpg
# []
# Elapsed time = 0.5787091255187988[s]
# sideshow_bob_7.jpg
# []
# Elapsed time = 0.5798697471618652[s]
# sideshow_bob_8.jpg
# []
# Elapsed time = 0.5754470825195312[s]
# sideshow_bob_9.jpg
# []
# Elapsed time = 0.5939393043518066[s]

# %% [markdown]
# ####【問題2】コードリーディング
# 上記実装のコードリーディングを行ってください。
#
# まず、Faster R-CNN[1]において重要だと考えた部分を列挙してください。そして、それに対応するコードを見つけてください。
#
# （例）
#
# - RPNを実現しているコードはどこか
# - RoIプーリングを実現しているコードはどこか
#
# フレームワークには畳み込み層など一般的なものはクラスが用意されていますが、RoIプーリングなど特定の手法限定のものは用意されていません。オリジナルのレイヤーを作成することが可能であり、Kerasであれば以下のページに情報がまとまっています。
#
# [オリジナルのKerasレイヤーを作成する - Keras Documentation](https://keras.io/ja/layers/writing-your-own-keras-layers/)
#
# 《参考》
#
# KerasではVGG16のクラスが用意されているため、簡単に利用ができます。include_top=Falseの引数を与えることで、出力のための全結合層部分が除かれます。weights='imagenet'でImageNetを利用した学習済みモデルも手に入り、転移学習 が行えます。weights='None'とすればランダムな初期化となります。
#
# [Applications - Keras Documentation](https://keras.io/ja/applications/#vgg16)

# %% [markdown]
#     RPNを実現しているコードはどこか
#     RoIプーリングを実現しているコードはどこか
#     Anchor とAnchorBoxを実現しているコードはどこか
#     GrandTruethを読み込んでいるコードはどこか

# %% [markdown]
#  RPN
#     #model/data_generators.py
#       def calc_rpn
#
#     # def rpn(base_layers,num_anchors):
#       x = Convolution2D(512, (3, 3), padding='same', activation='relu', kernel_initializer='normal', name='rpn_conv1')(base_layers)
#       x_class = Convolution2D(num_anchors, (1, 1), activation='sigmoid', kernel_initializer='uniform', name='rpn_out_class')(x)
#       x_regr = Convolution2D(num_anchors * 4, (1, 1), activation='linear', kernel_initializer='zero', name='rpn_out_regress')(x)
#       return [x_class, x_regr, base_layers]
#
#     # define the RPN, built on the base layers
#       num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
#       rpn = nn.rpn(shared_layers, num_anchoRPNRPN
#
#     # defining the models and a model that holds both the RPN and the classifier
#       model_rpn = Model(img_input, rpn[:2])
#       model_rpn.compile(optimizer=Adam(lr=1e-4), loss=[losses.rpn_loss_cls(num_anchors), losses.rpn_loss_regr(num_anchors)])
#
#   RoIプーリング
#     #model/resnet.py
#       from model.RoiPoolingConv import RoiPoolingConv
#
#     # RoiPoolingConv.py
#
#
# Anchor Box
#     #model/config.py
#    		# anchor box scales
# 		self.anchor_box_scales = [64, 128, 256, 512]
#
# 		# anchor box ratios
# 		self.anchor_box_ratios = [[1, 1], [1, 2], [2, 1]]
#
#  read GrandTrueth
#     # parser.add_argument("-p", "--path", default=None, help="path to annotation file")

# %% [markdown]
# ### 3.YOLOv3
#
#
# シンプソンズのデータセットをFaster R-CNN以外の手法で学習・推定を行います。YOLOv3[2]のKeras実装を使います。
#
# [qqwweee/keras-yolo3: A Keras implementation of YOLOv3 (Tensorflow backend)](https://github.com/qqwweee/keras-yolo3)
#
# [2]Jeseph Redmon, Ali Farhadi. YOLOv3: An Incremental Improvement
#
# [https://pjreddie.com/media/files/papers/YOLOv3.pdf](https://pjreddie.com/media/files/papers/YOLOv3.pdf)
#
# #### 【問題3】学習済みの重みによる推定
# 学習済みの重みを使い推定を行う方法がREADME.mdのQuick Startの項に記載されています。
#
# まずはこの通りにして各自何かしらの画像や動画に対して検出を行ってください。
#
# 出力結果を課題の一部として提出してください。

# %%
# !git clone https://github.com/qqwweee/keras-yolo3.git
# Out:
# Cloning into 'keras-yolo3'...
# remote: Enumerating objects: 144, done.
# remote: Total 144 (delta 0), reused 0 (delta 0), pack-reused 144
# Receiving objects: 100% (144/144), 151.08 KiB | 7.95 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# %mv /content/keras-yolo3 /content/drive/MyDrive
# Out:
# mv: cannot move '/content/keras-yolo3' to '/content/drive/MyDrive': No such file or directory

# %%
# カレントディレクトリの変更

import os

os.chdir('/content/drive/MyDrive/keras-yolo3')

# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content/drive/MyDrive/keras-yolo3

# %%
ls
# Out:
# coco_annotation.py  kmeans.py     train_bottleneck.py  yolov3.cfg
# convert.py          LICENSE       train.py             yolov3-tiny.cfg
# darknet53.cfg       model_data/   voc_annotation.py    yolov3.weights
# darknet53.weights   __pycache__/  yolo3/               yolo_video.py
# font/               README.md     yolo.py

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2021-03-26 08:48:09--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  12.5MB/s    in 20s
#
# 2021-03-26 08:48:29 (12.1 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# %mv /content/drive/MyDrive/yolov3.weights /content/drive/MyDrive/keras-yolo3

# %%
# カレントディレクトリの変更

import os

os.chdir('/content/drive/MyDrive/keras-yolo3')

# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content/drive/MyDrive/keras-yolo3

# %%
ls
# Out:
# coco_annotation.py  kmeans.py     train_bottleneck.py  yolov3.cfg
# convert.py          LICENSE       train.py             yolov3-tiny.cfg
# darknet53.cfg       model_data/   voc_annotation.py    yolov3.weights
# darknet53.weights   __pycache__/  yolo3/               yolo_video.py
# font/               README.md     yolo.py

# %%
! python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-03-29 06:15:15.545610: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-03-29 06:15:15.550290: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# 2021-03-29 06:15:15.550553: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c303d2ea00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-03-29 06:15:15.550584: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-03-29 06:15:15.553816: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-03-29 06:15:15.713702: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:15:15.714526: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c303d2f640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-03-29 06:15:15.714561: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-03-29 06:15:15.715707: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:15:15.716262: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-03-29 06:15:15.729086: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-29 06:15:15.941275: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-03-29 06:15:16.030397: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-03-29 06:15:16.049583: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-03-29 06:15:16.281185: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-03-29 06:15:16.429493: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-03-29 06:15:16.931710: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-29 06:15:16.931900: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:15:16.932601: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:15:16.933141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-03-29 06:15:16.933222: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-29 06:15:16.935238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-29 06:15:16.935272: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-03-29 06:15:16.935283: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-03-29 06:15:16.935399: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:15:16.935967: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:15:16.936507: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-03-29 06:15:16.936555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# Parsing section convolutional_1
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section convolutional_2
# conv2d bn leaky (1, 1, 64, 32)
# Parsing section convolutional_3
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section shortcut_0
# Parsing section convolutional_4
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section convolutional_5
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_6
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_1
# Parsing section convolutional_7
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_8
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_2
# Parsing section convolutional_9
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_10
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_11
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_3
# Parsing section convolutional_12
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_13
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_4
# Parsing section convolutional_14
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_15
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_5
# Parsing section convolutional_16
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_17
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_6
# Parsing section convolutional_18
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_19
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_7
# Parsing section convolutional_20
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_21
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_8
# Parsing section convolutional_22
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_23
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_9
# Parsing section convolutional_24
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_25
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_10
# Parsing section convolutional_26
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_27
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_28
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_11
# Parsing section convolutional_29
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_30
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_12
# Parsing section convolutional_31
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_32
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_13
# Parsing section convolutional_33
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_34
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_14
# Parsing section convolutional_35
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_36
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_15
# Parsing section convolutional_37
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_38
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_16
# Parsing section convolutional_39
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_40
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_17
# Parsing section convolutional_41
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_42
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_18
# Parsing section convolutional_43
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_44
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_45
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_19
# Parsing section convolutional_46
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_47
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_20
# Parsing section convolutional_48
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_49
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_21
# Parsing section convolutional_50
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_51
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_22
# Parsing section convolutional_52
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_53
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_54
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_55
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_56
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_57
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_58
# conv2d    linear (1, 1, 1024, 255)
# Parsing section yolo_0
# Parsing section route_0
# Parsing section convolutional_59
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section upsample_0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Parsing section route_1
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_1/ResizeNearestNeighbor:0' shape=(?, ?, ?, 256) dtype=float32>, <tf.Tensor 'add_19/add:0' shape=(?, ?, ?, 512) dtype=float32>]
# Parsing section convolutional_60
# conv2d bn leaky (1, 1, 768, 256)
# Parsing section convolutional_61
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_62
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_63
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_64
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_65
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_66
# conv2d    linear (1, 1, 512, 255)
# Parsing section yolo_1
# Parsing section route_2
# Parsing section convolutional_67
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section upsample_1
# Parsing section route_3
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_2/ResizeNearestNeighbor:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'add_11/add:0' shape=(?, ?, ?, 256) dtype=float32>]
# Parsing section convolutional_68
# conv2d bn leaky (1, 1, 384, 128)
# Parsing section convolutional_69
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_70
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_71
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_72
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_73
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_74
# conv2d    linear (1, 1, 256, 255)
# Parsing section yolo_2
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 18432       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 2048        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 6 18432       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 6 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 6 0           leaky_re_lu_2[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 6 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 73728       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 6 8192        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 6 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 8192        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 1 512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 1 0           add_2[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, None, None, 1 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 2 294912      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 2 1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 1 512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 2 1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 2 0           leaky_re_lu_10[0][0]
#                                                                  leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 32768       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 1 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 2 1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 2 0           add_4[0][0]
#                                                                  leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 1 32768       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 1 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 2 1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 2 0           add_5[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 32768       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 1 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 2 1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 2 0           add_6[0][0]
#                                                                  leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 32768       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 1 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 2 1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 2 0           add_7[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 1 32768       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 1 512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 2 1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 2 0           add_8[0][0]
#                                                                  leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 1 32768       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 1 512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 2 1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 2 0           add_9[0][0]
#                                                                  leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 1 32768       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 1 512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 2 1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 2 0           add_10[0][0]
#                                                                  leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, None, None, 2 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 5 1179648     zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 5 2048        conv2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 2 1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 5 2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 5 0           leaky_re_lu_27[0][0]
#                                                                  leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 2 131072      add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 2 1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 5 2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 5 0           add_12[0][0]
#                                                                  leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 2 131072      add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 2 1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 5 2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 5 0           add_13[0][0]
#                                                                  leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 2 131072      add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 2 1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 5 2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 5 0           add_14[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 2 131072      add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 2 1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 5 2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 5 0           add_15[0][0]
#                                                                  leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 2 131072      add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 2 1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 5 2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 5 0           add_16[0][0]
#                                                                  leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 2 131072      add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 2 1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 5 2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 5 0           add_17[0][0]
#                                                                  leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 2 131072      add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 2 1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 5 2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 5 0           add_18[0][0]
#                                                                  leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, None, None, 5 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 4718592     zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 4096        conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 5 2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 4096        conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# ...
# batch_normalization_50 (BatchNo (None, None, None, 1 4096        conv2d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 1 0           add_21[0][0]
#                                                                  leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 5 524288      add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 5 2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 4096        conv2d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 1 0           add_22[0][0]
#                                                                  leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 5 524288      add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 5 2048        conv2d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 1 4096        conv2d_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 5 2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 1 4096        conv2d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 5 2048        conv2d_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 2 1024        conv2d_60[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 2 0           leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 7 0           up_sampling2d_1[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 2 196608      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 2 1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 5 2048        conv2d_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 2 1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 5 2048        conv2d_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 2 1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 1 512         conv2d_68[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 1 0           leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 3 0           up_sampling2d_2[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 1 49152       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 2 1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 512         conv2d_71[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, None, None, 2 1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 1 512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 1 4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 5 2048        conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, None, None, 2 1024        conv2d_74[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 2 261375      leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 2 130815      leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 2 65535       leaky_re_lu_72[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# None
# Saved Keras model to model_data/yolo.h5
# Read 62001757 of 62001757.0 from Darknet weights.

# %%
# !python yolo_video.py --image
# Out:
# Using TensorFlow backend.
# Image detection mode
#  Ignoring remaining command line arguments: ./path2your_video,
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-03-29 06:16:56.734256: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-03-29 06:16:56.742238: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# 2021-03-29 06:16:56.742452: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561c5e718a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-03-29 06:16:56.742475: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-03-29 06:16:56.744313: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-03-29 06:16:56.843638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:16:56.844473: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561c5e719640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-03-29 06:16:56.844511: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-03-29 06:16:56.844694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:16:56.845224: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-03-29 06:16:56.845537: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-29 06:16:56.846591: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-03-29 06:16:56.847604: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-03-29 06:16:56.847977: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-03-29 06:16:56.849202: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-03-29 06:16:56.850114: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-03-29 06:16:56.853019: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-29 06:16:56.853127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:16:56.853772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:16:56.854278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-03-29 06:16:56.854333: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-29 06:16:56.855319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-29 06:16:56.855347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-03-29 06:16:56.855357: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-03-29 06:16:56.855468: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:16:56.856019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 06:16:56.856547: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-03-29 06:16:56.856594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# model_data/yolo.h5 model, anchors, and classes loaded.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Input image filename:/content/drive/MyDrive/Google フォト/2017/1160325.jpg
# (416, 416, 3)
# 2021-03-29 06:19:39.548167: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 06:19:39.729023: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] layout failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 06:19:39.943196: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 06:19:40.571015: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-29 06:19:44.916013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# Found 2 boxes for img
# car 0.98 (913, 227) (3472, 2252)
# person 0.30 (4182, 10) (4578, 673)
# 8.540917047000221
# Input image filename:Traceback (most recent call last):
#   File "yolo_video.py", line 73, in <module>
#   File "yolo_video.py", line 8, in detect_img
#     img = input('Input image filename:')
# KeyboardInterrupt

# %% [markdown]
# 【問題4】学習のためのファイルを作成
# 新しいデータ（シンプソンズデータセット）を学習します。README.mdのTrainingの項を読み、シンプソンズデータセットを学習するために必要なファイルを作成してください。
#
# アノテーションファイルの形式が問題1の実装とは異なるため変換する必要があります。

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-03-29 08:04:14--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  19.2MB/s    in 9.5s
#
# 2021-03-29 08:04:25 (16.3 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
# !python convert.py -w darknet53.cfg darknet53.weights model_data/darknet53_weights.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [0]
# Parsing Darknet config.
# Creating Keras model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-03-29 08:05:29.102553: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-03-29 08:05:29.107202: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# 2021-03-29 08:05:29.107400: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559e66416a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-03-29 08:05:29.107443: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-03-29 08:05:29.109144: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-03-29 08:05:29.211700: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:05:29.212524: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559e66417640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-03-29 08:05:29.212563: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-03-29 08:05:29.212742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:05:29.213272: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-03-29 08:05:29.213632: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-29 08:05:29.214699: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-03-29 08:05:29.215719: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-03-29 08:05:29.216035: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-03-29 08:05:29.217324: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-03-29 08:05:29.218262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-03-29 08:05:29.221288: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-29 08:05:29.221412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:05:29.222059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:05:29.222588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-03-29 08:05:29.222644: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-29 08:05:29.223604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-29 08:05:29.223633: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-03-29 08:05:29.223648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-03-29 08:05:29.223755: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:05:29.224308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:05:29.224865: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-03-29 08:05:29.224908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# Parsing section convolutional_1
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section convolutional_2
# conv2d bn leaky (1, 1, 64, 32)
# Parsing section convolutional_3
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section shortcut_0
# Parsing section convolutional_4
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section convolutional_5
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_6
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_1
# Parsing section convolutional_7
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_8
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_2
# Parsing section convolutional_9
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_10
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_11
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_3
# Parsing section convolutional_12
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_13
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_4
# Parsing section convolutional_14
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_15
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_5
# Parsing section convolutional_16
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_17
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_6
# Parsing section convolutional_18
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_19
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_7
# Parsing section convolutional_20
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_21
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_8
# Parsing section convolutional_22
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_23
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_9
# Parsing section convolutional_24
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_25
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_10
# Parsing section convolutional_26
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_27
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_28
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_11
# Parsing section convolutional_29
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_30
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_12
# Parsing section convolutional_31
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_32
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_13
# Parsing section convolutional_33
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_34
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_14
# Parsing section convolutional_35
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_36
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_15
# Parsing section convolutional_37
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_38
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_16
# Parsing section convolutional_39
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_40
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_17
# Parsing section convolutional_41
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_42
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_18
# Parsing section convolutional_43
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_44
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_45
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_19
# Parsing section convolutional_46
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_47
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_20
# Parsing section convolutional_48
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_49
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_21
# Parsing section convolutional_50
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_51
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_22
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 18432       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 2048        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 6 18432       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 6 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 6 0           leaky_re_lu_2[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 6 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 73728       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 6 8192        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 6 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 8192        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 1 512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 1 0           add_2[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, None, None, 1 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 2 294912      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 2 1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 1 512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 2 1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 2 0           leaky_re_lu_10[0][0]
#                                                                  leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 32768       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 1 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 2 1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 2 0           add_4[0][0]
#                                                                  leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 1 32768       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 1 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 2 1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 2 0           add_5[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 32768       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 1 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 2 1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 2 0           add_6[0][0]
#                                                                  leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 32768       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 1 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 2 1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 2 0           add_7[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 1 32768       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 1 512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 2 1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 2 0           add_8[0][0]
#                                                                  leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 1 32768       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 1 512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 2 1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 2 0           add_9[0][0]
#                                                                  leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 1 32768       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 1 512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 2 1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 2 0           add_10[0][0]
#                                                                  leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, None, None, 2 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 5 1179648     zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 5 2048        conv2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 2 1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 5 2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 5 0           leaky_re_lu_27[0][0]
#                                                                  leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 2 131072      add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 2 1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 5 2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 5 0           add_12[0][0]
#                                                                  leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 2 131072      add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 2 1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 5 2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 5 0           add_13[0][0]
#                                                                  leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 2 131072      add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 2 1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 5 2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 5 0           add_14[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 2 131072      add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 2 1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 5 2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 5 0           add_15[0][0]
#                                                                  leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 2 131072      add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 2 1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 5 2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 5 0           add_16[0][0]
#                                                                  leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 2 131072      add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 2 1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 5 2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 5 0           add_17[0][0]
#                                                                  leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 2 131072      add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 2 1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 5 2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 5 0           add_18[0][0]
#                                                                  leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, None, None, 5 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 4718592     zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 4096        conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 5 2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 4096        conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 1 0           leaky_re_lu_44[0][0]
#                                                                  leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 5 524288      add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 5 2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 4096        conv2d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 1 0           add_20[0][0]
#                                                                  leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 5 524288      add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 5 2048        conv2d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 1 4096        conv2d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 1 0           add_21[0][0]
#                                                                  leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 5 524288      add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 5 2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 4096        conv2d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 1 0           add_22[0][0]
#                                                                  leaky_re_lu_52[0][0]
# ==================================================================================================
# Total params: 40,620,640
# Trainable params: 40,584,928
# Non-trainable params: 35,712
# __________________________________________________________________________________________________
# None
# Saved Keras weights to model_data/darknet53_weights.h5
# Read 40620640 of 40620640.0 from Darknet weights.

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/keras-yolo3/train.txt")
df
# Out:
#       ./characters/abraham_grampa_simpson/pic_0000.jpg  ...  abraham_grampa_simpson
# 0     ./characters/abraham_grampa_simpson/pic_0001.jpg  ...  abraham_grampa_simpson
# 1     ./characters/abraham_grampa_simpson/pic_0002.jpg  ...  abraham_grampa_simpson
# 2     ./characters/abraham_grampa_simpson/pic_0003.jpg  ...  abraham_grampa_simpson
# 3     ./characters/abraham_grampa_simpson/pic_0004.jpg  ...  abraham_grampa_simpson
# 4     ./characters/abraham_grampa_simpson/pic_0005.jpg  ...  abraham_grampa_simpson
# ...                                                ...  ...                     ...
# 6746            ./characters/sideshow_bob/pic_0721.jpg  ...            sideshow_bob
# 6747            ./characters/sideshow_bob/pic_0779.jpg  ...            sideshow_bob
# 6748            ./characters/sideshow_bob/pic_0609.jpg  ...            sideshow_bob
# 6749            ./characters/sideshow_bob/pic_0427.jpg  ...            sideshow_bob
# 6750            ./characters/sideshow_bob/pic_0839.jpg  ...            sideshow_bob
#
# [6751 rows x 6 columns]

# %%
df["abraham_grampa_simpson"].unique()
# Out:
# array(['abraham_grampa_simpson', 'apu_nahasapeemapetilon', 'bart_simpson',
#        'charles_montgomery_burns', 'chief_wiggum', 'comic_book_guy',
#        'edna_krabappel', 'homer_simpson', 'kent_brockman',
#        'krusty_the_clown', 'lisa_simpson', 'marge_simpson',
#        'milhouse_van_houten', 'moe_szyslak', 'ned_flanders',
#        'nelson_muntz', 'principal_skinner', 'sideshow_bob'], dtype=object)

# %%
pd.read_csv("/content/drive/MyDrive/keras-yolo3/train.txt")
# Out:
#      /content/drive/MyDrive/keras-yolo3/characters/abraham_grampa_simpson/pic_0000.jpg  ...  20
# 0     /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  20
# 1     /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  20
# 2     /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  20
# 3     /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  20
# 4     /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  20
# ...                                                 ...                                 ...  ..
# 6746  /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  36
# 6747  /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  36
# 6748  /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  36
# 6749  /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  36
# 6750  /content/drive/MyDrive/keras-yolo3/characters/...                                 ...  36
#
# [6751 rows x 6 columns]

# %%
# !python  train.py model_data/yolo_weights.h5
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-03-29 08:27:10.734223: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-03-29 08:27:10.739017: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# 2021-03-29 08:27:10.739252: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5559618f0a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-03-29 08:27:10.739289: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-03-29 08:27:10.743213: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-03-29 08:27:10.851668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:27:10.852524: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5559618f1640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-03-29 08:27:10.852556: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-03-29 08:27:10.852717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:27:10.853254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-03-29 08:27:10.853657: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-29 08:27:10.855918: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-03-29 08:27:10.857074: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-03-29 08:27:10.857729: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-03-29 08:27:10.859533: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-03-29 08:27:10.860729: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-03-29 08:27:10.864340: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-29 08:27:10.864466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:27:10.865047: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:27:10.865558: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-03-29 08:27:10.865613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-29 08:27:10.866645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-29 08:27:10.866674: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-03-29 08:27:10.866685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-03-29 08:27:10.866797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:27:10.867346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-29 08:27:10.867906: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-03-29 08:27:10.867950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Create YOLOv3 model with 9 anchors and 38 classes.
# /usr/local/lib/python3.7/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_59 due to mismatch in shape ((1, 1, 1024, 129) vs (255, 1024, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.7/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_59 due to mismatch in shape ((129,) vs (255,)).
#   weight_values[i].shape))
# /usr/local/lib/python3.7/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_67 due to mismatch in shape ((1, 1, 512, 129) vs (255, 512, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.7/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_67 due to mismatch in shape ((129,) vs (255,)).
#   weight_values[i].shape))
# /usr/local/lib/python3.7/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_75 due to mismatch in shape ((1, 1, 256, 129) vs (255, 256, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.7/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_75 due to mismatch in shape ((129,) vs (255,)).
#   weight_values[i].shape))
# Load weights model_data/yolo_weights.h5.
# Freeze the first 249 layers of total 252 layers.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1521: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3080: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Train on 6077 samples, val on 675 samples, with batch size 32.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/50
# 2021-03-29 08:27:40.553734: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] shape_optimizer failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 08:27:40.592169: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 08:27:40.713173: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] layout failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 08:27:40.882056: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] shape_optimizer failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 08:27:40.941888: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 08:27:41.616334: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-29 08:27:42.525333: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 188/189 [============================>.] - ETA: 14s - loss: 757.50292021-03-29 09:12:54.354738: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 09:12:54.446798: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] layout failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-03-29 09:12:54.590574: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 189/189 [==============================] - 2853s 15s/step - loss: 753.9713 - val_loss: 83.7950
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/callbacks.py:995: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/50
# 189/189 [==============================] - 417s 2s/step - loss: 62.2788 - val_loss: 44.9268
# Epoch 3/50
# 189/189 [==============================] - 418s 2s/step - loss: 39.9543 - val_loss: 33.6921
# Epoch 4/50
# 189/189 [==============================] - 406s 2s/step - loss: 31.8061 - val_loss: 28.7646
# Epoch 5/50
# 189/189 [==============================] - 418s 2s/step - loss: 27.9906 - val_loss: 26.3042
# Epoch 6/50
# 189/189 [==============================] - 418s 2s/step - loss: 25.5012 - val_loss: 24.2149
# Epoch 7/50
# 167/189 [=========================>....] - ETA: 44s - loss: 24.2194Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/training_generator.py", line 181, in fit_generator
#     generator_output = next(output_generator)
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py", line 685, in get
#     inputs = self.queue.get(block=True).get()
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 651, in get
#     self.wait(timeout)
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 648, in wait
#     self._event.wait(timeout)
#   File "/usr/lib/python3.7/threading.py", line 552, in wait
#     signaled = self._cond.wait(timeout)
#   File "/usr/lib/python3.7/threading.py", line 296, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train.py", line 190, in <module>
#     _main()
#   File "train.py", line 65, in _main
#     callbacks=[logging, checkpoint])
#   File "/usr/local/lib/python3.7/dist-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1418, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/training_generator.py", line 262, in fit_generator
#     val_enqueuer.stop()
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py", line 493, in stop
#     self.queue.queue.clear()
# KeyboardInterrupt
